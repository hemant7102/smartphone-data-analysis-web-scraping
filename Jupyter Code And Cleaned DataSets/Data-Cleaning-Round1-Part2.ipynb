# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('smartphone_cleaned_v1.csv')

# %%
df.head()
# Out:
#    index                     model  price  rating  \
# 0      2           OPPO Reno 15 5G  39990    90.0
# 1      3  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4                   iQOO 15  67999    91.0
# 3      5           Realme GT 8 Pro  72999    94.0
# 4      6  Xiaomi Redmi K90 Pro Max  50990    91.0
#
#                                                  sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...
#
#                                            processor  \
# 0      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 3  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 4  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
# 3  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 120W Fast Charging
# 4  12 GB RAM, 256 GB inbuilt  7500 mAh Battery with 100W Fast Charging
#
#                                              display  \
# 0  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...
# 1  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...
# 2  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...
# 3  6.79 inches, 1440 x 3136 px, 144 Hz Display wi...
# 4  6.9 inches, 1200 x 2608 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3  200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os
# 0  Memory Card Not Supported  No FM Radio
# 1  Memory Card Not Supported  Android v14
# 2  Memory Card Not Supported  No FM Radio
# 3  Memory Card Not Supported  Android v16
# 4  Memory Card Not Supported  No FM Radio

# %%
# Copy of dataset

df1 = df.copy()

# %%
df1.head(3)
# Out:
#    index                     model  price  rating  \
# 0      2           OPPO Reno 15 5G  39990    90.0
# 1      3  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4                   iQOO 15  67999    91.0
#
#                                                  sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                            processor  \
# 0      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
#
#                                              display  \
# 0  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...
# 1  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...
# 2  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os
# 0  Memory Card Not Supported  No FM Radio
# 1  Memory Card Not Supported  Android v14
# 2  Memory Card Not Supported  No FM Radio

# %% [markdown]
# # Working with Columns

# %% [markdown]
# ### 1> Model col

# %%
brand_name = df['model'].str.split(' ').str.get(0)

# %%
df1.insert(1,'brand_name',brand_name)

# %%
df1.head()
# Out:
#    index brand_name                     model  price  rating  \
# 0      2       OPPO           OPPO Reno 15 5G  39990    90.0
# 1      3    Samsung  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4       iQOO                   iQOO 15  67999    91.0
# 3      5     Realme           Realme GT 8 Pro  72999    94.0
# 4      6     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0
#
#                                                  sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...
#
#                                            processor  \
# 0      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 3  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 4  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
# 3  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 120W Fast Charging
# 4  12 GB RAM, 256 GB inbuilt  7500 mAh Battery with 100W Fast Charging
#
#                                              display  \
# 0  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...
# 1  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...
# 2  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...
# 3  6.79 inches, 1440 x 3136 px, 144 Hz Display wi...
# 4  6.9 inches, 1200 x 2608 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3  200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os
# 0  Memory Card Not Supported  No FM Radio
# 1  Memory Card Not Supported  Android v14
# 2  Memory Card Not Supported  No FM Radio
# 3  Memory Card Not Supported  Android v16
# 4  Memory Card Not Supported  No FM Radio

# %%
df1['brand_name'].value_counts()
# Out:
# brand_name
# Samsung      128
# Vivo         128
# Realme       106
# Xiaomi        70
# Motorola      63
# Oppo          52
# OnePlus       50
# iQOO          44
# Poco          38
# Infinix       36
# Apple         34
# OPPO          31
# Tecno         28
# Lava          25
# Honor         23
# Google        20
# Nothing       18
# Nubia         11
# Nokia          9
# Peace          6
# itel           5
# CMF            5
# HMD            5
# Huawei         5
# Ai+            4
# Asus           4
# Oneplus        3
# Jio            2
# Doogee         2
# Alcatel        2
# Oukitel        2
# Vertu          2
# Sony           2
# POCO           2
# Light          2
# Ulefone        2
# RedMagic       1
# Wobble         1
# Red            1
# Tesla          1
# Unihertz       1
# Bluefox        1
# MTR            1
# LAVA           1
# ZTE            1
# iKall          1
# Redmi          1
# Acer           1
# Energizer      1
# Cubot          1
# Micromax       1
# Name: count, dtype: int64

# %% [markdown]
# ### 2> Sim Col

# %%
has_5g = df1['sim'].str.contains('5G')

has_nfc = df1['sim'].str.contains('NFC')

has_ir_blaster = df1['sim'].str.contains('IR Blaster')

# %%
df1.insert(6, 'has_5g', has_5g)

df1.insert(7, 'has_nfc', has_nfc)

df1.insert(8, 'has_ir_blaster', has_ir_blaster)

# %%
df1.head()
# Out:
#    index brand_name                     model  price  rating  \
# 0      2       OPPO           OPPO Reno 15 5G  39990    90.0
# 1      3    Samsung  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4       iQOO                   iQOO 15  67999    91.0
# 3      5     Realme           Realme GT 8 Pro  72999    94.0
# 4      6     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0
#
#                                                  sim  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True     True
#
#    has_ir_blaster                                          processor  \
# 0            True      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1           False    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 3            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 4            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
# 3  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 120W Fast Charging
# 4  12 GB RAM, 256 GB inbuilt  7500 mAh Battery with 100W Fast Charging
#
#                                              display  \
# 0  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...
# 1  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...
# 2  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...
# 3  6.79 inches, 1440 x 3136 px, 144 Hz Display wi...
# 4  6.9 inches, 1200 x 2608 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3  200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os
# 0  Memory Card Not Supported  No FM Radio
# 1  Memory Card Not Supported  Android v14
# 2  Memory Card Not Supported  No FM Radio
# 3  Memory Card Not Supported  Android v16
# 4  Memory Card Not Supported  No FM Radio

# %% [markdown]
# ### 3> Processor Col

# %%
processor_name = df1['processor'].str.split(',').str.get(0)

num_cores = df1['processor'].str.split(',').str.get(1)

processor_speed = df1['processor'].str.split(',').str.get(2)

# %%
df1.insert(10,'processor_name',processor_name)

df1.insert(11,'num_cores',num_cores)

df1.insert(12,'processor_speed',processor_speed)

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 6300              88
# Octa Core Processor         52
# Dimensity 7300              32
# Snapdragon 8 Elite          32
# Snapdragon 8 Elite Gen 5    27
#                             ..
# Snapdragon 435               1
# Unisoc T7100                 1
# Apple A20 Pro                1
# 4 GB RAM                     1
# Exynos 850                   1
# Name: count, Length: 199, dtype: int64

# %%
df1['processor_name'] = df1['processor_name'].str.strip()

# %%
temp_df = df1[df1['processor_name'].str.contains('core', na=False)][
    ['processor_name', 'num_cores', 'processor_speed']
].shift(1,axis=1)

# %%
temp_df
# Out:
# Empty DataFrame
# Columns: [processor_name, num_cores, processor_speed]
# Index: []

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name', 'num_cores',
#        'processor_speed', 'ram', 'battery', 'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df1.loc[temp_df.index,['processor_name','num_cores','processor_speed']] = temp_df.values

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 6300              88
# Octa Core Processor         52
# Dimensity 7300              32
# Snapdragon 8 Elite          32
# Snapdragon 8 Elite Gen 5    27
#                             ..
# Snapdragon 435               1
# Unisoc T7100                 1
# Apple A20 Pro                1
# 4 GB RAM                     1
# Exynos 850                   1
# Name: count, Length: 199, dtype: int64

# %%
df1[df1['processor_name'] == '(28 nm)']
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor, processor_name, num_cores, processor_speed, ram, battery, display, camera, card, os]
# Index: []

# %%
df1.loc[856,'processor_name'] = 'Mediatek MT6739'

# %%
df1.loc[856]
# Out:
# index                                                            880
# brand_name                                                      Acer
# model                            Acer Super ZX 5G  (6GB RAM + 128GB)
# price                                                          11999
# rating                                                           NaN
# sim                               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# has_5g                                                          True
# has_nfc                                                        False
# has_ir_blaster                                                 False
# processor               Dimensity 6300, Octa Core, 2.4 GHz Processor
# processor_name                                       Mediatek MT6739
# num_cores                                                  Octa Core
# processor_speed                                    2.4 GHz Processor
# ram                                         6 GB RAM, 128 GB inbuilt
# battery                      5000 mAh Battery with 33W Fast Charging
# display            6.8 inches, 1080 x 2400 px, 120 Hz Display wit...
# camera             64 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# card                                       Memory Card Not Supported
# os                                                         Bluetooth
# Name: 856, dtype: object

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 6300              87
# Octa Core Processor         52
# Snapdragon 8 Elite          32
# Dimensity 7300              32
# Snapdragon 8 Elite Gen 5    27
#                             ..
# Snapdragon 435               1
# Unisoc T7100                 1
# Apple A20 Pro                1
# 4 GB RAM                     1
# Exynos 850                   1
# Name: count, Length: 200, dtype: int64

# %%
processor_brand = df1['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
df1.insert(11,'processor_brand',processor_brand)

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core              796
# Octa Core Processor     66
# Hexa Core               20
# Hexa Core Processor     11
# Deca Core                8
# Single Core              5
# Quad Core                4
# 2 GHz Processor          2
# 512 MHz Processor        1
# Deca Core Processor      1
# Nine-Cores               1
# Nine Cores               1
# 2.5 GHz Processor        1
# Nine Core                1
# Dual Core                1
# 1.3 GHz Processor        1
# 1.4 GHz Processor        1
# 1.6 GHz Processor        1
# 64 GB inbuilt            1
# Name: count, dtype: int64

# %%
df1['num_cores'] = df1['num_cores'].str.strip()

# %%
df1['num_cores'] = df1['num_cores'].str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core')

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core              862
# Hexa Core               31
# Deca Core                8
# Single Core              5
# Quad Core                4
# 2 GHz Processor          2
# 512 MHz Processor        1
# Deca Core Processor      1
# Nine-Cores               1
# Nine Cores               1
# 2.5 GHz Processor        1
# Nine Core                1
# Dual Core                1
# 1.3 GHz Processor        1
# 1.4 GHz Processor        1
# 1.6 GHz Processor        1
# 64 GB inbuilt            1
# Name: count, dtype: int64

# %%
df1['processor_speed'].value_counts()
# Out:
# processor_speed
# 2.4 GHz Processor     157
# 2.5 GHz Processor     118
# 2.2 GHz Processor      77
# 3.2 GHz Processor      38
# 2.6 GHz Processor      34
# 3.35 GHz Processor     33
# 2.8 GHz Processor      33
# 4.32 GHz Processor     32
# 3 GHz Processor        31
# 2.3 GHz Processor      29
# 2 GHz Processor        24
# 3.25 GHz Processor     24
# 4.6 GHz Processor      22
# 3.3 GHz Processor      20
# 2.63 GHz Processor     20
# 1.8 GHz Processor      18
# 3.63 GHz Processor     15
# 3.1 GHz Processor      14
# 4.47 GHz Processor     13
# 2.7 GHz Processor      11
# 4.04 GHz Processor      7
# 4.05 GHz Processor      6
# 4.21 GHz Processor      5
# 2.9 GHz Processor       5
# 3.36 GHz Processor      5
# 1.3 MHz Processor       5
# 1.6 GHz Processor       5
# 2.85 GHz Processor      4
# 3.46 GHz Processor      4
# 3.4 GHz Processor       4
# 1.1 GHz Processor       3
# 3.22 GHz Processor      3
# 2.96 GHz Processor      3
# 2.84 GHz Processor      3
# 3.11 GHz Processor      2
# 1.4 GHz Processor       2
# 3.05 GHz Processor      2
# 2.1 GHz Processor       2
# 1.3 GHz Processor       1
# 2.91 GHz Processor      1
# 3.39 GHz Processor      1
# 2.05 GHz Processor      1
# Name: count, dtype: int64

# %%
df1 = df1[~df1['processor_speed'].isin(['Mediatek MT6739'])]

# %%
df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)

# %%
df1['processor_brand']
# Out:
# 0       dimensity
# 1      snapdragon
# 2      snapdragon
# 3      snapdragon
# 4      snapdragon
#           ...
# 979     dimensity
# 980    snapdragon
# 981     dimensity
# 982     dimensity
# 983    snapdragon
# Name: processor_brand, Length: 984, dtype: object

# %% [markdown]
# ### 4> Ram Col

# %%
ram_capacity = df1['ram'].str.strip().str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df1.insert(16,'ram_capacity',ram_capacity)

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8       422
# 12      262
# 6       110
# 4       106
# 16       54
# 3        10
# 2         4
# 24        3
# 512       3
# 1         2
# 256       2
# 128       1
# 32        1
# 7000      1
# 5100      1
# Name: count, dtype: int64

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.strip().str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(17,'internal_memory',internal_memory)

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8       422
# 12      262
# 6       110
# 4       106
# 16       54
# 3        10
# 2         4
# 24        3
# 512       3
# 1         2
# 256       2
# 128       1
# 32        1
# 7000      1
# 5100      1
# Name: count, dtype: int64

# %%
df1['ram_capacity'] = df1['ram_capacity'].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            984 non-null    int64
#  1   brand_name       984 non-null    object
#  2   model            984 non-null    object
#  3   price            984 non-null    int64
#  4   rating           603 non-null    float64
#  5   sim              984 non-null    object
#  6   has_5g           984 non-null    bool
#  7   has_nfc          984 non-null    bool
#  8   has_ir_blaster   984 non-null    bool
#  9   processor        984 non-null    object
#  10  processor_name   984 non-null    object
#  11  processor_brand  984 non-null    object
#  12  num_cores        923 non-null    object
#  13  processor_speed  837 non-null    float64
#  14  ram              984 non-null    object
#  15  battery          958 non-null    object
#  16  ram_capacity     982 non-null    float64
#  17  internal_memory  977 non-null    object
#  18  display          984 non-null    object
#  19  camera           984 non-null    object
#  20  card             984 non-null    object
#  21  os               984 non-null    object
# dtypes: bool(3), float64(3), int64(2), object(14)
# memory usage: 149.1+ KB

# %%
df1[df1['ram_capacity'] > 18]
# Out:
#      index brand_name                                        model   price  \
# 270    275      Apple                         Apple iPhone 16 Plus   76490
# 310    315      Nokia                              Nokia 2780 Flip    4990
# 320    325     Realme                                   Realme C85   14990
# 380    387    OnePlus                   OnePlus 13 (24GB RAM+ 1TB)   83999
# 423    430      Peace                                 Peace Mini 4    4649
# 632    646      Nokia                            Nokia 2720 V Flip    6199
# 661    678      Apple                 Apple iPhone 16 Plus (256GB)   89900
# 838    861     Huawei                               Huawei Nova 15   39990
# 872    899      Nubia  Nubia Red Magic 9 Pro Plus (24GB RAM + 1TB)   80990
# 924    953      Nokia                                Nokia 8000 4G    6899
# 949    979       Vivo                                    Vivo Y04s    7999
# 973   1004       Asus                 Asus ROG Phone 9 Pro Edition  126990
#
#      rating                                                sim  has_5g  \
# 270    82.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 310     NaN                            Dual Sim, 3G, 4G, Wi-Fi   False
# 320     NaN                   Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC    True
# 380    93.0  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True
# 423     NaN                            Dual Sim, 3G, 4G, Wi-Fi   False
# 632     NaN                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 661    83.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 838     NaN       Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC, IR Blaster    True
# 872    88.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 924     NaN                            Dual Sim, 3G, 4G, Wi-Fi   False
# 949     NaN                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 973    93.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
#
#      has_nfc  has_ir_blaster  \
# 270     True           False
# 310    False           False
# 320     True           False
# 380     True            True
# 423    False           False
# 632    False           False
# 661     True           False
# 838     True            True
# 872     True           False
# 924    False           False
# 949    False           False
# 973     True           False
#
#                                              processor      processor_name  \
# 270          Bionic A18, Hexa Core, 4.04 GHz Processor          Bionic A18
# 310     Snapdragon QM215, Quad Core, 1.3 GHz Processor    Snapdragon QM215
# 320       Dimensity 6300, Octa Core, 2.4 GHz Processor      Dimensity 6300
# 380  Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor  Snapdragon 8 Elite
# 423              Helio, Single Core, 1.3 MHz Processor               Helio
# 632      Snapdragon 205 , Dual Core, 1.1 GHz Processor      Snapdragon 205
# 661          Bionic A18, Hexa Core, 4.04 GHz Processor          Bionic A18
# 838                                     256 GB inbuilt      256 GB inbuilt
# 872    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor   Snapdragon 8 Gen3
# 924      Snapdragon  210, Quad Core, 1.1 GHz Processor     Snapdragon  210
# 949                            4 GB RAM, 64 GB inbuilt            4 GB RAM
# 973  Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor  Snapdragon 8 Elite
#
#     processor_brand      num_cores  processor_speed  \
# 270          bionic      Hexa Core             4.04
# 310      snapdragon      Quad Core             1.30
# 320       dimensity      Octa Core             2.40
# 380      snapdragon      Octa Core             4.32
# 423           helio    Single Core             1.30
# 632      snapdragon      Dual Core             1.10
# 661          bionic      Hexa Core             4.04
# 838             256            NaN              NaN
# 872      snapdragon      Octa Core             3.30
# 924      snapdragon      Quad Core             1.10
# 949               4  64 GB inbuilt              NaN
# 973      snapdragon      Octa Core             4.32
#
#                                           ram  \
# 270                            128 GB inbuilt
# 310                  512 MB RAM, 4 GB inbuilt
# 320                            256 GB inbuilt
# 380                   24 GB RAM, 1 TB inbuilt
# 423                   32 GB RAM, 3 GB inbuilt
# 632                  512 MB RAM, 4 GB inbuilt
# 661                            256 GB inbuilt
# 838  7000 mAh Battery with 100W Fast Charging
# 872                   24 GB RAM, 1 TB inbuilt
# 924                  512 MB RAM, 4 GB inbuilt
# 949   5100 mAh Battery with 18W Fast Charging
# 973                   24 GB RAM, 1 TB inbuilt
#
#                                                battery  ram_capacity  \
# 270                4674 mAh Battery with Fast Charging         128.0
# 310                                   1450 mAh Battery         512.0
# 320            7000 mAh Battery with 45W Fast Charging         256.0
# 380           6000 mAh Battery with 100W Fast Charging          24.0
# 423                                   2000 mAh Battery          32.0
# 632                                   1500 mAh Battery         512.0
# 661                4674 mAh Battery with Fast Charging         256.0
# 838                 6.7 inches, 1084 x 2412 px Display        7000.0
# 872           5500 mAh Battery with 165W Fast Charging          24.0
# 924                                   1500 mAh Battery         512.0
# 949  6.67 inches, 720 x 1600 px, 90 Hz Display with...        5100.0
# 973            5800 mAh Battery with 65W Fast Charging          24.0
#
#     internal_memory                                            display  \
# 270             NaN  6.7 inches, 1290 x 2796 px Display with Dynami...
# 310               4                   2.7 inches, 240 x 320 px Display
# 320             NaN  6.8 inches, 720 x 1570 px, 144 Hz Display with...
# 380               1  6.82 inches, 1440 x 3168 px, 120 Hz Display wi...
# 423               3                  3.75 inches, 412 x 960 px Display
# 632               4                   2.8 inches, 240 x 320 px Display
# 661             NaN  6.7 inches, 1290 x 2796 px Display with Dynami...
# 838             NaN  50 MP + 12 MP + 12 MP Triple Rear & 50 MP Fron...
# 872               1         6.8 inches, 1116 x 2480 px, 120 Hz Display
# 924               4                   2.8 inches, 240 x 320 px Display
# 949             NaN         13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 973               1  6.78 inches, 1080 x 2400 px, 185 Hz Display wi...
#
#                                                 camera  \
# 270       48 MP + 12 MP Dual Rear & 12 MP Front Camera
# 310                                       Dual Display
# 320                     50 MP Rear & 8 MP Front Camera
# 380  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 423                                   8 MP Rear Camera
# 632                                       Dual Display
# 661       48 MP + 12 MP Dual Rear & 12 MP Front Camera
# 838                                                 v6
# 872  50 MP + 50 MP + 2 MP Triple Rear & 16 MP Front...
# 924                                   2 MP Rear Camera
# 949                   Memory Card Supported, upto 1 TB
# 973  50 MP + 32 MP + 13 MP Triple Rear & 32 MP Fron...
#
#                           card                                 os
# 270  Memory Card Not Supported                            iOS v18
# 310  Memory Card Not Supported  Memory Card Supported, upto 32 GB
# 320      Memory Card Supported                        Android v15
# 380  Memory Card Not Supported                        Android v15
# 423  Memory Card Not Supported                        No FM Radio
# 632  Memory Card Not Supported              Memory Card Supported
# 661  Memory Card Not Supported                            iOS v18
# 838  Memory Card Not Supported                          Bluetooth
# 872  Memory Card Not Supported                        No FM Radio
# 924      Memory Card Supported                          Bluetooth
# 949  Memory Card Not Supported                          Bluetooth
# 973  Memory Card Not Supported                        No FM Radio

# %%
df1.loc[[439,762],['ram_capacity','internal_memory']] == [[4.0,'64'],[4.0,'64']]
# Out:
#      ram_capacity  internal_memory
# 439         False            False
# 762         False            False

# %%
df1.loc[483, ['ram_capacity', 'internal_memory']] == pd.Series(
    {'ram_capacity': 12.0, 'internal_memory': '512'}
)
# Out:
# ram_capacity       False
# internal_memory    False
# dtype: bool

# %%
df1.drop([486,627],inplace=True)

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8.0       421
# 12.0      261
# 6.0       110
# 4.0       106
# 16.0       54
# 3.0        10
# 2.0         4
# 24.0        3
# 512.0       3
# 1.0         2
# 256.0       2
# 128.0       1
# 32.0        1
# 7000.0      1
# 5100.0      1
# Name: count, dtype: int64

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 256    407
# 128    395
# 512     99
# 64      48
# 1       11
# 32       8
# 4        3
# 8        2
# 3        1
# 12       1
# Name: count, dtype: int64

# %%
df1['internal_memory'] = df1['internal_memory'].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 983
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            982 non-null    int64
#  1   brand_name       982 non-null    object
#  2   model            982 non-null    object
#  3   price            982 non-null    int64
#  4   rating           601 non-null    float64
#  5   sim              982 non-null    object
#  6   has_5g           982 non-null    bool
#  7   has_nfc          982 non-null    bool
#  8   has_ir_blaster   982 non-null    bool
#  9   processor        982 non-null    object
#  10  processor_name   982 non-null    object
#  11  processor_brand  982 non-null    object
#  12  num_cores        921 non-null    object
#  13  processor_speed  836 non-null    float64
#  14  ram              982 non-null    object
#  15  battery          956 non-null    object
#  16  ram_capacity     980 non-null    float64
#  17  internal_memory  975 non-null    float64
#  18  display          982 non-null    object
#  19  camera           982 non-null    object
#  20  card             982 non-null    object
#  21  os               982 non-null    object
# dtypes: bool(3), float64(4), int64(2), object(13)
# memory usage: 156.3+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 983
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            982 non-null    int64
#  1   brand_name       982 non-null    object
#  2   model            982 non-null    object
#  3   price            982 non-null    int64
#  4   rating           601 non-null    float64
#  5   sim              982 non-null    object
#  6   has_5g           982 non-null    bool
#  7   has_nfc          982 non-null    bool
#  8   has_ir_blaster   982 non-null    bool
#  9   processor        982 non-null    object
#  10  processor_name   982 non-null    object
#  11  processor_brand  982 non-null    object
#  12  num_cores        921 non-null    object
#  13  processor_speed  836 non-null    float64
#  14  ram              982 non-null    object
#  15  battery          956 non-null    object
#  16  ram_capacity     980 non-null    float64
#  17  internal_memory  975 non-null    float64
#  18  display          982 non-null    object
#  19  camera           982 non-null    object
#  20  card             982 non-null    object
#  21  os               982 non-null    object
# dtypes: bool(3), float64(4), int64(2), object(13)
# memory usage: 156.3+ KB

# %%
df1[df1['internal_memory'] < 32]
# Out:
#      index brand_name                                        model   price  \
# 273    278    Samsung     Samsung Galaxy Z Fold 7 (16GB RAM + 1TB)  216999
# 310    315      Nokia                              Nokia 2780 Flip    4990
# 379    386    Samsung    Samsung Galaxy S25 Ultra (12GB RAM + 1TB)  165999
# 380    387    OnePlus                   OnePlus 13 (24GB RAM+ 1TB)   83999
# 423    430      Peace                                 Peace Mini 4    4649
# 469    477      Apple                Apple iPhone 17 Pro Max (1TB)  189900
# 632    646      Nokia                            Nokia 2720 V Flip    6199
# 651    668    Samsung    Samsung Galaxy S25 Ultra (16GB RAM + 1TB)  175999
# 656    673      Nubia                               Nubia Neo 3 GT   23990
# 835    856     Xiaomi                              Xiaomi Redmi Go    5199
# 847    871    Ulefone                       Ulefone Armor 29 Ultra   70990
# 872    899      Nubia  Nubia Red Magic 9 Pro Plus (24GB RAM + 1TB)   80990
# 873    900      Apple                Apple iPhone 16 Pro Max (1TB)  167900
# 878    905      Light                                Light Phone 2   24990
# 889    916      Nokia                            Nokia 235 4G 2024    3749
# 924    953      Nokia                                Nokia 8000 4G    6899
# 973   1004       Asus                 Asus ROG Phone 9 Pro Edition  126990
# 983   1017    OnePlus                 OnePlus Open 5G Apex Edition  149998
#
#      rating                                                sim  has_5g  \
# 273    97.0      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True
# 310     NaN                            Dual Sim, 3G, 4G, Wi-Fi   False
# 379    94.0      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True
# 380    93.0  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True
# 423     NaN                            Dual Sim, 3G, 4G, Wi-Fi   False
# 469    83.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 632     NaN                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 651    95.0      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True
# 656     NaN            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 835     NaN                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 847    96.0       Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC, IR Blaster    True
# 872    88.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 873    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 878     NaN                          Single Sim, 3G, 4G, VoLTE   False
# 889     NaN                            Dual Sim, 3G, 4G, VoLTE   False
# 924     NaN                            Dual Sim, 3G, 4G, Wi-Fi   False
# 973    93.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 983    94.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
#
#      has_nfc  has_ir_blaster  \
# 273     True           False
# 310    False           False
# 379     True           False
# 380     True            True
# 423    False           False
# 469     True           False
# 632    False           False
# 651     True           False
# 656     True           False
# 835    False           False
# 847     True            True
# 872     True           False
# 873     True           False
# 878    False           False
# 889    False           False
# 924    False           False
# 973     True           False
# 983     True            True
#
#                                              processor  \
# 273  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 310     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 379  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 380  Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor
# 423              Helio, Single Core, 1.3 MHz Processor
# 469                 Apple A19 Pro, Hexa Core Processor
# 632      Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 651   Snapdragon 8Elite, Octa Core, 4.47 GHz Processor
# 656         Unisoc T9100, Octa Core, 2.7 GHz Processor
# 835   Snapdragon MSM8917, Quad Core, 1.4 GHz Processor
# 847  Dimensity 9300 Plus, Octa Core, 3.25 GHz Proce...
# 872    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 873      Bionic A18 Pro, Hexa Core, 4.05 GHz Processor
# 878       Snapdragon 210, Quad Core, 1.1 GHz Processor
# 889                                            No Wifi
# 924      Snapdragon  210, Quad Core, 1.1 GHz Processor
# 973  Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor
# 983    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                     processor_name processor_brand    num_cores  \
# 273  Snapdragon 8 Elite for Galaxy      snapdragon    Octa Core
# 310               Snapdragon QM215      snapdragon    Quad Core
# 379  Snapdragon 8 Elite for Galaxy      snapdragon    Octa Core
# 380             Snapdragon 8 Elite      snapdragon    Octa Core
# 423                          Helio           helio  Single Core
# 469                  Apple A19 Pro           apple    Hexa Core
# 632                 Snapdragon 205      snapdragon    Dual Core
# 651              Snapdragon 8Elite      snapdragon    Octa Core
# 656                   Unisoc T9100          unisoc    Octa Core
# 835             Snapdragon MSM8917      snapdragon    Quad Core
# 847            Dimensity 9300 Plus       dimensity    Octa Core
# 872              Snapdragon 8 Gen3      snapdragon    Octa Core
# 873                 Bionic A18 Pro          bionic    Hexa Core
# 878                 Snapdragon 210      snapdragon    Quad Core
# 889                        No Wifi              no          NaN
# 924                Snapdragon  210      snapdragon    Quad Core
# 973             Snapdragon 8 Elite      snapdragon    Octa Core
# 983              Snapdragon 8 Gen2      snapdragon    Octa Core
#
#      processor_speed                           ram  \
# 273             4.47       16 GB RAM, 1 TB inbuilt
# 310             1.30      512 MB RAM, 4 GB inbuilt
# 379             4.47       12 GB RAM, 1 TB inbuilt
# 380             4.32       24 GB RAM, 1 TB inbuilt
# 423             1.30       32 GB RAM, 3 GB inbuilt
# 469              NaN       12 GB RAM, 1 TB inbuilt
# 632             1.10      512 MB RAM, 4 GB inbuilt
# 651             4.47       16 GB RAM, 1 TB inbuilt
# 656             2.70       8 GB RAM, 12 GB inbuilt
# 835             1.40        1 GB RAM, 8 GB inbuilt
# 847             3.25       16 GB RAM, 1 TB inbuilt
# 872             3.30       24 GB RAM, 1 TB inbuilt
# 873             4.05        8 GB RAM, 1 TB inbuilt
# 878             1.10        1 GB RAM, 8 GB inbuilt
# 889              NaN  Unisoc T107, 1 GHz Processor
# 924             1.10      512 MB RAM, 4 GB inbuilt
# 973             4.32       24 GB RAM, 1 TB inbuilt
# 983             3.20       16 GB RAM, 1 TB inbuilt
#
#                                        battery  ram_capacity  internal_memory  \
# 273    4400 mAh Battery with 25W Fast Charging          16.0              1.0
# 310                           1450 mAh Battery         512.0              4.0
# 379    5000 mAh Battery with 45W Fast Charging          12.0              1.0
# 380   6000 mAh Battery with 100W Fast Charging          24.0              1.0
# 423                           2000 mAh Battery          32.0              3.0
# 469        4832 mAh Battery with Fast Charging          12.0              1.0
# 632                           1500 mAh Battery         512.0              4.0
# 651    5000 mAh Battery with 45W Fast Charging          16.0              1.0
# 656    6000 mAh Battery with 80W Fast Charging           8.0             12.0
# 835                           3000 mAh Battery           1.0              8.0
# 847  21200 mAh Battery with 120W Fast Charging          16.0              1.0
# 872   5500 mAh Battery with 165W Fast Charging          24.0              1.0
# 873        4685 mAh Battery with Fast Charging           8.0              1.0
# 878                            950 mAh Battery           1.0              8.0
# 889                                        NaN           NaN              1.0
# 924                           1500 mAh Battery         512.0              4.0
# 973    5800 mAh Battery with 65W Fast Charging          24.0              1.0
# 983    4805 mAh Battery with 67W Fast Charging          16.0              1.0
#
#                                                display  \
# 273  8 inches, 1968 x 2184 px, 120 Hz Display with ...
# 310                   2.7 inches, 240 x 320 px Display
# 379  6.9 inches, 1440 x 3120 px, 120 Hz Display wit...
# 380  6.82 inches, 1440 x 3168 px, 120 Hz Display wi...
# 423                  3.75 inches, 412 x 960 px Display
# 469  6.9 inches, 1320 x 2868 px, 120 Hz Display wit...
# 632                   2.8 inches, 240 x 320 px Display
# 651  6.9 inches, 1440 x 3120 px, 120 Hz Display wit...
# 656  6.8 inches, 1080 x 2392 px, 120 Hz Display wit...
# 835                    5 inches, 720 x 1280 px Display
# 847  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 872         6.8 inches, 1116 x 2480 px, 120 Hz Display
# 873  6.9 inches, 1320 x 2868 px, 120 Hz Display wit...
# 878                                 2.8 inches Display
# 889                          64 MB RAM, 128 MB inbuilt
# 924                   2.8 inches, 240 x 320 px Display
# 973  6.78 inches, 1080 x 2400 px, 185 Hz Display wi...
# 983  7.82 inches, 2268 x 2440 px, 120 Hz Display wi...
#
#                                                 camera  \
# 273                     Foldable Display, Dual Display
# 310                                       Dual Display
# 379              200 MP Quad Rear & 12 MP Front Camera
# 380  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 423                                   8 MP Rear Camera
# 469  48 MP + 48 MP + 48 MP Triple Rear & 18 MP Fron...
# 632                                       Dual Display
# 651              200 MP Quad Rear & 12 MP Front Camera
# 656  Main + Depth Sensor Dual Rear & Ultra Wide Fro...
# 835                      8 MP Rear & 5 MP Front Camera
# 847                                       Dual Display
# 872  50 MP + 50 MP + 2 MP Triple Rear & 16 MP Front...
# 873  48 MP + 48 MP + 12 MP Triple Rear & 12 MP Fron...
# 878                                     No Rear Camera
# 889                   2.8 inches, 240 x 320 px Display
# 924                                   2 MP Rear Camera
# 973  50 MP + 32 MP + 13 MP Triple Rear & 32 MP Fron...
# 983                     Foldable Display, Dual Display
#
#                                    card                                 os
# 273           Memory Card Not Supported                        Android v16
# 310           Memory Card Not Supported  Memory Card Supported, upto 32 GB
# 379           Memory Card Not Supported                        Android v15
# 380           Memory Card Not Supported                        Android v15
# 423           Memory Card Not Supported                        No FM Radio
# 469           Memory Card Not Supported                            iOS v26
# 632           Memory Card Not Supported              Memory Card Supported
# 651           Memory Card Not Supported                        Android v15
# 656           Memory Card Not Supported                        No FM Radio
# 835  Memory Card Supported, upto 128 GB                Android v8.1 (Oreo)
# 847           Memory Card Not Supported              Memory Card Supported
# 872           Memory Card Not Supported                        No FM Radio
# 873           Memory Card Not Supported                            iOS v18
# 878           Memory Card Not Supported                        No FM Radio
# 889           Memory Card Not Supported                   2 MP Rear Camera
# 924               Memory Card Supported                          Bluetooth
# 973           Memory Card Not Supported                        No FM Radio
# 983           Memory Card Not Supported          Memory Card Not Supported

# %%
temp_df = df1[df1['internal_memory'] == 1]

# %%
df1.loc[temp_df.index, 'internal_memory'] = 1024

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 256.0     407
# 128.0     395
# 512.0      99
# 64.0       48
# 1024.0     11
# 32.0        8
# 4.0         3
# 8.0         2
# 3.0         1
# 12.0        1
# Name: count, dtype: int64

# %% [markdown]
# ### 5> Battery Col

# %%
df1['battery']
# Out:
# 0       6200 mAh Battery with 80W Fast Charging
# 1       5000 mAh Battery with 45W Fast Charging
# 2      7000 mAh Battery with 100W Fast Charging
# 3      7000 mAh Battery with 120W Fast Charging
# 4      7500 mAh Battery with 100W Fast Charging
#                          ...
# 979     5000 mAh Battery with 18W Fast Charging
# 980     5000 mAh Battery with 44W Fast Charging
# 981     5100 mAh Battery with 45W Fast Charging
# 982     5000 mAh Battery with 10W Fast Charging
# 983     4805 mAh Battery with 67W Fast Charging
# Name: battery, Length: 982, dtype: object

# %%
battery_capacity = df1['battery'].str.strip().str.split('with').str.get(0)

# %%
battery_capacity
# Out:
# 0      6200 mAh Battery
# 1      5000 mAh Battery
# 2      7000 mAh Battery
# 3      7000 mAh Battery
# 4      7500 mAh Battery
#              ...
# 979    5000 mAh Battery
# 980    5000 mAh Battery
# 981    5100 mAh Battery
# 982    5000 mAh Battery
# 983    4805 mAh Battery
# Name: battery, Length: 982, dtype: object

# %%
df1.insert(16,'battery_capacity',battery_capacity)

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram', 'battery',
#        'battery_capacity', 'ram_capacity', 'internal_memory', 'display',
#        'camera', 'card', 'os'],
#       dtype='object')

# %%
df1['battery_capacity'] = df1['battery_capacity'].str.strip().str.split().str.get(0)

# %%
df1['battery_capacity'].value_counts()
# Out:
# battery_capacity
# 5000     242
# 6000     127
# 7000      91
# 5500      84
# 6500      41
#         ...
# 6.3        1
# 22000      1
# 11000      1
# 6.67       1
# 4805       1
# Name: count, Length: 119, dtype: int64

# %%
fast_charging = df1['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')

# %%
df1.insert(17,'fast_charging',fast_charging)

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
# [80]     143
# [45]     135
# [25]      78
# [90]      73
# [100]     70
# [33]      66
# []        56
# [120]     46
# [18]      45
# [44]      38
# [15]      38
# [67]      25
# [30]      20
# [65]      13
# [68]      12
# [66]      12
# [10]      10
# [150]      8
# [50]       8
# [60]       6
# [35]       6
# [20]       6
# [70]       3
# [27]       3
# [23]       1
# [320]      1
# [55]       1
# [125]      1
# [48]       1
# [85]       1
# [40]       1
# [250]      1
# [165]      1
# [22]       1
# Name: count, dtype: int64

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
# [80]     143
# [45]     135
# [25]      78
# [90]      73
# [100]     70
# [33]      66
# []        56
# [120]     46
# [18]      45
# [44]      38
# [15]      38
# [67]      25
# [30]      20
# [65]      13
# [68]      12
# [66]      12
# [10]      10
# [150]      8
# [50]       8
# [60]       6
# [35]       6
# [20]       6
# [70]       3
# [27]       3
# [23]       1
# [320]      1
# [55]       1
# [125]      1
# [48]       1
# [85]       1
# [40]       1
# [250]      1
# [165]      1
# [22]       1
# Name: count, dtype: int64

# %%
def fast_charging_extractor(item):

    if type(item) == list:
        if len(item) == 1:
            return item[0]

        else:
            return 0
    else:
        return -1

# %%
df1['fast_charging'] = df1['fast_charging'].apply(fast_charging_extractor).astype(int)

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
#  80     143
#  45     135
#  25      78
#  90      73
#  100     70
#  33      66
#  0       56
# -1       52
#  120     46
#  18      45
#  44      38
#  15      38
#  67      25
#  30      20
#  65      13
#  68      12
#  66      12
#  10      10
#  150      8
#  50       8
#  60       6
#  35       6
#  20       6
#  70       3
#  27       3
#  23       1
#  320      1
#  55       1
#  125      1
#  48       1
#  85       1
#  40       1
#  250      1
#  165      1
#  22       1
# Name: count, dtype: int64

# %% [markdown]
# ### 6> Display Col

# %%
screen_size = df1['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0)

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram', 'battery',
#        'battery_capacity', 'fast_charging', 'ram_capacity', 'internal_memory',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df1.insert(21,'screen_size',screen_size)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 983
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             982 non-null    int64
#  1   brand_name        982 non-null    object
#  2   model             982 non-null    object
#  3   price             982 non-null    int64
#  4   rating            601 non-null    float64
#  5   sim               982 non-null    object
#  6   has_5g            982 non-null    bool
#  7   has_nfc           982 non-null    bool
#  8   has_ir_blaster    982 non-null    bool
#  9   processor         982 non-null    object
#  10  processor_name    982 non-null    object
#  11  processor_brand   982 non-null    object
#  12  num_cores         921 non-null    object
#  13  processor_speed   836 non-null    float64
#  14  ram               982 non-null    object
#  15  battery           956 non-null    object
#  16  battery_capacity  956 non-null    object
#  17  fast_charging     982 non-null    int64
#  18  ram_capacity      980 non-null    float64
#  19  internal_memory   975 non-null    float64
#  20  display           982 non-null    object
#  21  screen_size       982 non-null    object
#  22  camera            982 non-null    object
#  23  card              982 non-null    object
#  24  os                982 non-null    object
# dtypes: bool(3), float64(4), int64(3), object(15)
# memory usage: 211.6+ KB

# %%
# Extract numeric value and convert to float
df1['screen_size'] = df1['screen_size'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 983
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             982 non-null    int64
#  1   brand_name        982 non-null    object
#  2   model             982 non-null    object
#  3   price             982 non-null    int64
#  4   rating            601 non-null    float64
#  5   sim               982 non-null    object
#  6   has_5g            982 non-null    bool
#  7   has_nfc           982 non-null    bool
#  8   has_ir_blaster    982 non-null    bool
#  9   processor         982 non-null    object
#  10  processor_name    982 non-null    object
#  11  processor_brand   982 non-null    object
#  12  num_cores         921 non-null    object
#  13  processor_speed   836 non-null    float64
#  14  ram               982 non-null    object
#  15  battery           956 non-null    object
#  16  battery_capacity  956 non-null    object
#  17  fast_charging     982 non-null    int64
#  18  ram_capacity      980 non-null    float64
#  19  internal_memory   975 non-null    float64
#  20  display           982 non-null    object
#  21  screen_size       981 non-null    float64
#  22  camera            982 non-null    object
#  23  card              982 non-null    object
#  24  os                982 non-null    object
# dtypes: bool(3), float64(5), int64(3), object(14)
# memory usage: 211.6+ KB

# %%
resolution = df1['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

# %%
df1.insert(22,'resolution',resolution)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 983
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             982 non-null    int64
#  1   brand_name        982 non-null    object
#  2   model             982 non-null    object
#  3   price             982 non-null    int64
#  4   rating            601 non-null    float64
#  5   sim               982 non-null    object
#  6   has_5g            982 non-null    bool
#  7   has_nfc           982 non-null    bool
#  8   has_ir_blaster    982 non-null    bool
#  9   processor         982 non-null    object
#  10  processor_name    982 non-null    object
#  11  processor_brand   982 non-null    object
#  12  num_cores         921 non-null    object
#  13  processor_speed   836 non-null    float64
#  14  ram               982 non-null    object
#  15  battery           956 non-null    object
#  16  battery_capacity  956 non-null    object
#  17  fast_charging     982 non-null    int64
#  18  ram_capacity      980 non-null    float64
#  19  internal_memory   975 non-null    float64
#  20  display           982 non-null    object
#  21  screen_size       981 non-null    float64
#  22  resolution        948 non-null    object
#  23  camera            982 non-null    object
#  24  card              982 non-null    object
#  25  os                982 non-null    object
# dtypes: bool(3), float64(5), int64(3), object(15)
# memory usage: 219.3+ KB

# %%
refresh_rate = df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0).apply(lambda x:60 if pd.isna(x) else x).astype(int)

# %%
df1.insert(23,'refresh_rate',refresh_rate)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 983
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             982 non-null    int64
#  1   brand_name        982 non-null    object
#  2   model             982 non-null    object
#  3   price             982 non-null    int64
#  4   rating            601 non-null    float64
#  5   sim               982 non-null    object
#  6   has_5g            982 non-null    bool
#  7   has_nfc           982 non-null    bool
#  8   has_ir_blaster    982 non-null    bool
#  9   processor         982 non-null    object
#  10  processor_name    982 non-null    object
#  11  processor_brand   982 non-null    object
#  12  num_cores         921 non-null    object
#  13  processor_speed   836 non-null    float64
#  14  ram               982 non-null    object
#  15  battery           956 non-null    object
#  16  battery_capacity  956 non-null    object
#  17  fast_charging     982 non-null    int64
#  18  ram_capacity      980 non-null    float64
#  19  internal_memory   975 non-null    float64
#  20  display           982 non-null    object
#  21  screen_size       981 non-null    float64
#  22  resolution        948 non-null    object
#  23  refresh_rate      982 non-null    int64
#  24  camera            982 non-null    object
#  25  card              982 non-null    object
#  26  os                982 non-null    object
# dtypes: bool(3), float64(5), int64(4), object(15)
# memory usage: 227.0+ KB

# %%
df1.head()
# Out:
#    index brand_name                     model  price  rating  \
# 0      2       OPPO           OPPO Reno 15 5G  39990    90.0
# 1      3    Samsung  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4       iQOO                   iQOO 15  67999    91.0
# 3      5     Realme           Realme GT 8 Pro  72999    94.0
# 4      6     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0
#
#                                                  sim  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True     True
#
#    has_ir_blaster                                          processor  \
# 0            True      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1           False    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 3            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 4            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#              processor_name processor_brand  num_cores  processor_speed  \
# 0            Dimensity 8450       dimensity  Octa Core             3.25
# 1         Snapdragon 8 Gen3      snapdragon  Octa Core             3.30
# 2  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 3  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 4  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
# 3  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 120W Fast Charging
# 4  12 GB RAM, 256 GB inbuilt  7500 mAh Battery with 100W Fast Charging
#
#   battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 0             6200             80          12.0            256.0
# 1             5000             45          12.0            256.0
# 2             7000            100          12.0            256.0
# 3             7000            120          12.0            256.0
# 4             7500            100          12.0            256.0
#
#                                              display  screen_size  \
# 0  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...         6.32
# 1  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...         6.80
# 2  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...         6.85
# 3  6.79 inches, 1440 x 3136 px, 144 Hz Display wi...         6.79
# 4  6.9 inches, 1200 x 2608 px, 120 Hz Display wit...         6.90
#
#      resolution  refresh_rate  \
# 0  1216 x 2640            120
# 1  1440 x 3120            120
# 2  1440 x 3168            144
# 3  1440 x 3136            144
# 4  1200 x 2608            120
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3  200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os
# 0  Memory Card Not Supported  No FM Radio
# 1  Memory Card Not Supported  Android v14
# 2  Memory Card Not Supported  No FM Radio
# 3  Memory Card Not Supported  Android v16
# 4  Memory Card Not Supported  No FM Radio

# %% [markdown]
# ## 7> Camera Col

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                58
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera               46
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera               37
# 50 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera    29
# 50 MP + 2 MP Dual Rear & 32 MP Front Camera               28
#                                                           ..
# 48 MP Quad Rear & 13 MP Front Camera                       1
# 50 MP + 13 MP Dual Rear & 8 MP Front Camera                1
# Memory Card Supported, upto 1 TB                           1
# 50 MP + 12 MP Dual Rear & 16 MP Front Camera               1
# 48 MP + Depth Sensor Dual Rear & 8 MP Front Camera         1
# Name: count, Length: 225, dtype: int64

# %%
df1['camera']
# Out:
# 0      200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1                  200 MP Quad Rear & 12 MP Front Camera
# 2      50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3      200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4      50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#                              ...
# 979    48 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 980          50 MP + 2 MP Dual Rear & 32 MP Front Camera
# 981                  50 MP Dual Rear & 5 MP Front Camera
# 982                  32 MP Dual Rear & 8 MP Front Camera
# 983                       Foldable Display, Dual Display
# Name: camera, Length: 982, dtype: object

# %%
def  camera_extractor(text):

    if 'Quad' in text:
        return 4
    elif 'Triple' in text:
        return 3
    elif 'Dual' in text:
        return 2
    elif 'Missing' in text:
        return 'Missing'
    else:
        return 1

# %%
num_rear_camera = df1['camera'].str.strip().str.split('&').str.get(0).apply(camera_extractor)

# %%
df1.insert(20,'num_rear_camera',num_rear_camera)

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram', 'battery',
#        'battery_capacity', 'fast_charging', 'ram_capacity', 'internal_memory',
#        'num_rear_camera', 'display', 'screen_size', 'resolution',
#        'refresh_rate', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df1.head()
# Out:
#    index brand_name                     model  price  rating  \
# 0      2       OPPO           OPPO Reno 15 5G  39990    90.0
# 1      3    Samsung  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4       iQOO                   iQOO 15  67999    91.0
# 3      5     Realme           Realme GT 8 Pro  72999    94.0
# 4      6     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0
#
#                                                  sim  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True     True
#
#    has_ir_blaster                                          processor  \
# 0            True      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1           False    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 3            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 4            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#              processor_name processor_brand  num_cores  processor_speed  \
# 0            Dimensity 8450       dimensity  Octa Core             3.25
# 1         Snapdragon 8 Gen3      snapdragon  Octa Core             3.30
# 2  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 3  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 4  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
# 3  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 120W Fast Charging
# 4  12 GB RAM, 256 GB inbuilt  7500 mAh Battery with 100W Fast Charging
#
#   battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 0             6200             80          12.0            256.0
# 1             5000             45          12.0            256.0
# 2             7000            100          12.0            256.0
# 3             7000            120          12.0            256.0
# 4             7500            100          12.0            256.0
#
#    num_rear_camera                                            display  \
# 0                3  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...
# 1                4  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...
# 2                3  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...
# 3                3  6.79 inches, 1440 x 3136 px, 144 Hz Display wi...
# 4                3  6.9 inches, 1200 x 2608 px, 120 Hz Display wit...
#
#    screen_size    resolution  refresh_rate  \
# 0         6.32  1216 x 2640            120
# 1         6.80  1440 x 3120            120
# 2         6.85  1440 x 3168            144
# 3         6.79  1440 x 3136            144
# 4         6.90  1200 x 2608            120
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3  200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os
# 0  Memory Card Not Supported  No FM Radio
# 1  Memory Card Not Supported  Android v14
# 2  Memory Card Not Supported  No FM Radio
# 3  Memory Card Not Supported  Android v16
# 4  Memory Card Not Supported  No FM Radio

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram', 'battery',
#        'battery_capacity', 'fast_charging', 'ram_capacity', 'internal_memory',
#        'num_rear_camera', 'display', 'screen_size', 'resolution',
#        'refresh_rate', 'camera', 'card', 'os'],
#       dtype='object')

# %%
num_front_camera = df1['camera'].str.strip().str.split('&').str.get(1).str.strip()

# %%
df1.insert(21,'num_front_camera',num_front_camera)

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram', 'battery',
#        'battery_capacity', 'fast_charging', 'ram_capacity', 'internal_memory',
#        'num_rear_camera', 'num_front_camera', 'display', 'screen_size',
#        'resolution', 'refresh_rate', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 983
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             982 non-null    int64
#  1   brand_name        982 non-null    object
#  2   model             982 non-null    object
#  3   price             982 non-null    int64
#  4   rating            601 non-null    float64
#  5   sim               982 non-null    object
#  6   has_5g            982 non-null    bool
#  7   has_nfc           982 non-null    bool
#  8   has_ir_blaster    982 non-null    bool
#  9   processor         982 non-null    object
#  10  processor_name    982 non-null    object
#  11  processor_brand   982 non-null    object
#  12  num_cores         921 non-null    object
#  13  processor_speed   836 non-null    float64
#  14  ram               982 non-null    object
#  15  battery           956 non-null    object
#  16  battery_capacity  956 non-null    object
#  17  fast_charging     982 non-null    int64
#  18  ram_capacity      980 non-null    float64
#  19  internal_memory   975 non-null    float64
#  20  num_rear_camera   982 non-null    int64
#  21  num_front_camera  926 non-null    object
#  22  display           982 non-null    object
#  23  screen_size       981 non-null    float64
#  24  resolution        948 non-null    object
#  25  refresh_rate      982 non-null    int64
#  26  camera            982 non-null    object
#  27  card              982 non-null    object
#  28  os                982 non-null    object
# dtypes: bool(3), float64(5), int64(5), object(16)
# memory usage: 242.3+ KB

# %%
a = df1[df1['num_front_camera'].isnull()]

# %%
len(a)
# Out:
# 56

# %%
df1[df1['num_front_camera'] == 'Missing']
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor, processor_name, processor_brand, num_cores, processor_speed, ram, battery, battery_capacity, fast_charging, ram_capacity, internal_memory, num_rear_camera, num_front_camera, display, screen_size, resolution, refresh_rate, camera, card, os]
# Index: []

# %%
pd.set_option('display.max_columns',None)

# %%
df1.head()
# Out:
#    index brand_name                     model  price  rating  \
# 0      2       OPPO           OPPO Reno 15 5G  39990    90.0
# 1      3    Samsung  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4       iQOO                   iQOO 15  67999    91.0
# 3      5     Realme           Realme GT 8 Pro  72999    94.0
# 4      6     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0
#
#                                                  sim  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True     True
#
#    has_ir_blaster                                          processor  \
# 0            True      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1           False    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 3            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 4            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#              processor_name processor_brand  num_cores  processor_speed  \
# 0            Dimensity 8450       dimensity  Octa Core             3.25
# 1         Snapdragon 8 Gen3      snapdragon  Octa Core             3.30
# 2  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 3  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 4  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
# 3  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 120W Fast Charging
# 4  12 GB RAM, 256 GB inbuilt  7500 mAh Battery with 100W Fast Charging
#
#   battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 0             6200             80          12.0            256.0
# 1             5000             45          12.0            256.0
# 2             7000            100          12.0            256.0
# 3             7000            120          12.0            256.0
# 4             7500            100          12.0            256.0
#
#    num_rear_camera    num_front_camera  \
# 0                3  50 MP Front Camera
# 1                4  12 MP Front Camera
# 2                3  32 MP Front Camera
# 3                3  32 MP Front Camera
# 4                3  32 MP Front Camera
#
#                                              display  screen_size  \
# 0  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...         6.32
# 1  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...         6.80
# 2  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...         6.85
# 3  6.79 inches, 1440 x 3136 px, 144 Hz Display wi...         6.79
# 4  6.9 inches, 1200 x 2608 px, 120 Hz Display wit...         6.90
#
#      resolution  refresh_rate  \
# 0  1216 x 2640            120
# 1  1440 x 3120            120
# 2  1440 x 3168            144
# 3  1440 x 3136            144
# 4  1200 x 2608            120
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3  200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os
# 0  Memory Card Not Supported  No FM Radio
# 1  Memory Card Not Supported  Android v14
# 2  Memory Card Not Supported  No FM Radio
# 3  Memory Card Not Supported  Android v16
# 4  Memory Card Not Supported  No FM Radio

# %%
df1[df1['camera']== 'Foldable Display,Dual Display']
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor, processor_name, processor_brand, num_cores, processor_speed, ram, battery, battery_capacity, fast_charging, ram_capacity, internal_memory, num_rear_camera, num_front_camera, display, screen_size, resolution, refresh_rate, camera, card, os]
# Index: []

# %%
df1.loc[69,'camera']=='50 MP'
# Out:
# False

# %%
temp_df = df1[df1['camera']=='Foldable Display, Dual Display']

# %%
df1['camera']
# Out:
# 0      200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1                  200 MP Quad Rear & 12 MP Front Camera
# 2      50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3      200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4      50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#                              ...
# 979    48 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 980          50 MP + 2 MP Dual Rear & 32 MP Front Camera
# 981                  50 MP Dual Rear & 5 MP Front Camera
# 982                  32 MP Dual Rear & 8 MP Front Camera
# 983                       Foldable Display, Dual Display
# Name: camera, Length: 982, dtype: object

# %%
df1.loc[temp_df.index,'camera']='50 MP'

# %%
df1['primary_camera_front'] = df1['camera'].str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1['primary_camera_front'] = df1['camera'].str.split('&').str.get(1).str.strip(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1.head()
# Out:
#    index brand_name                     model  price  rating  \
# 0      2       OPPO           OPPO Reno 15 5G  39990    90.0
# 1      3    Samsung  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4       iQOO                   iQOO 15  67999    91.0
# 3      5     Realme           Realme GT 8 Pro  72999    94.0
# 4      6     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0
#
#                                                  sim  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True     True
#
#    has_ir_blaster                                          processor  \
# 0            True      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1           False    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 3            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 4            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#              processor_name processor_brand  num_cores  processor_speed  \
# 0            Dimensity 8450       dimensity  Octa Core             3.25
# 1         Snapdragon 8 Gen3      snapdragon  Octa Core             3.30
# 2  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 3  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 4  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
# 3  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 120W Fast Charging
# 4  12 GB RAM, 256 GB inbuilt  7500 mAh Battery with 100W Fast Charging
#
#   battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 0             6200             80          12.0            256.0
# 1             5000             45          12.0            256.0
# 2             7000            100          12.0            256.0
# 3             7000            120          12.0            256.0
# 4             7500            100          12.0            256.0
#
#    num_rear_camera    num_front_camera  \
# 0                3  50 MP Front Camera
# 1                4  12 MP Front Camera
# 2                3  32 MP Front Camera
# 3                3  32 MP Front Camera
# 4                3  32 MP Front Camera
#
#                                              display  screen_size  \
# 0  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...         6.32
# 1  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...         6.80
# 2  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...         6.85
# 3  6.79 inches, 1440 x 3136 px, 144 Hz Display wi...         6.79
# 4  6.9 inches, 1200 x 2608 px, 120 Hz Display wit...         6.90
#
#      resolution  refresh_rate  \
# 0  1216 x 2640            120
# 1  1440 x 3120            120
# 2  1440 x 3168            144
# 3  1440 x 3136            144
# 4  1200 x 2608            120
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3  200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os primary_camera_front
# 0  Memory Card Not Supported  No FM Radio                    5
# 1  Memory Card Not Supported  Android v14                    1
# 2  Memory Card Not Supported  No FM Radio                    3
# 3  Memory Card Not Supported  Android v16                    3
# 4  Memory Card Not Supported  No FM Radio                    3

# %% [markdown]
# ## 8> Card Col

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported             614
# Memory Card (Hybrid), upto 1 TB       111
# Memory Card Supported, upto 1 TB       62
# Memory Card (Hybrid), upto 2 TB        57
# Memory Card (Hybrid)                   48
# Memory Card Supported                  45
# Memory Card Supported, upto 2 TB       23
# Memory Card (Hybrid), upto 1.5 TB       7
# Memory Card Supported, upto 512 GB      6
# Memory Card Supported, upto 128 GB      4
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card Supported, upto 256 GB      1
# Memory Card (Hybrid), upto 1.02 TB      1
# Memory Card Supported, upto 32 GB       1
# Name: count, dtype: int64

# %%
df1[df1['card'] == 'Memory Card (Hybrid), upto 1 TB']
# Out:
#      index brand_name                                  model  price  rating  \
# 14      16   Motorola             Motorola Moto G67 Power 5G  16496    80.0
# 20      22    OnePlus                   OnePlus Nord CE 5 5G  24998    83.0
# 23      25     Xiaomi             Xiaomi Redmi Note 14 SE 5G  13630    80.0
# 31      33   Motorola                Motorola Edge 60 Fusion  20944    84.0
# 42      44   Motorola             Motorola Moto G86 Power 5G  17775    83.0
# ..     ...        ...                                    ...    ...     ...
# 913    942       iQOO           iQOO Z6 4G (6GB RAM + 128GB)  11590     NaN
# 919    948    Samsung                  Samsung Galaxy A73 5G  41999    88.0
# 939    969       Sony                     Sony Xperia 10 VII  46990    83.0
# 979   1013    Infinix  Infinix Hot 50 5G (8 GB RAM + 128 GB)  10999     NaN
# 980   1014       Vivo                         Vivo Y300 Plus  23999    80.0
#
#                                                 sim  has_5g  has_nfc  \
# 14               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 20   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 23   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 31         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi    True    False
# 42               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# ..                                              ...     ...      ...
# 913                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False
# 919         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 939         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 979              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 980              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#      has_ir_blaster                                          processor  \
# 14            False   Snapdragon 7s Gen2, Octa Core, 2.4 GHz Processor
# 20             True  Dimensity 8350 Apex, Octa Core, 3.35 GHz Proce...
# 23             True  Dimensity 7025 Ultra, Octa Core, 2.5 GHz Proce...
# 31            False       Dimensity 7400, Octa Core, 2.5 GHz Processor
# 42            False       Dimensity 7400, Octa Core, 2.6 GHz Processor
# ..              ...                                                ...
# 913           False      Snapdragon  680, Octa Core, 2.4 GHz Processor
# 919           False      Snapdragon 778G, Octa Core, 2.4 GHz Processor
# 939           False    Snapdragon 6 Gen3, Octa Core, 2.4 GHz Processor
# 979           False       Dimensity 6300, Octa Core, 2.4 GHz Processor
# 980           False       Snapdragon 695, Octa Core, 2.2 GHz Processor
#
#            processor_name processor_brand  num_cores  processor_speed  \
# 14     Snapdragon 7s Gen2      snapdragon  Octa Core             2.40
# 20    Dimensity 8350 Apex       dimensity  Octa Core             3.35
# 23   Dimensity 7025 Ultra       dimensity  Octa Core             2.50
# 31         Dimensity 7400       dimensity  Octa Core             2.50
# 42         Dimensity 7400       dimensity  Octa Core             2.60
# ..                    ...             ...        ...              ...
# 913       Snapdragon  680      snapdragon  Octa Core             2.40
# 919       Snapdragon 778G      snapdragon  Octa Core             2.40
# 939     Snapdragon 6 Gen3      snapdragon  Octa Core             2.40
# 979        Dimensity 6300       dimensity  Octa Core             2.40
# 980        Snapdragon 695      snapdragon  Octa Core             2.20
#
#                           ram                                  battery  \
# 14   8 GB RAM, 128 GB inbuilt  7000 mAh Battery with 30W Fast Charging
# 20   8 GB RAM, 128 GB inbuilt  7100 mAh Battery with 80W Fast Charging
# 23   6 GB RAM, 128 GB inbuilt  5110 mAh Battery with 45W Fast Charging
# 31   8 GB RAM, 256 GB inbuilt  5500 mAh Battery with 68W Fast Charging
# 42   8 GB RAM, 128 GB inbuilt  6720 mAh Battery with 33W Fast Charging
# ..                        ...                                      ...
# 913  6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 44W Fast Charging
# 919  8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 25W Fast Charging
# 939  8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 979  8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 980  8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 44W Fast Charging
#
#     battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 14              7000             30           8.0            128.0
# 20              7100             80           8.0            128.0
# 23              5110             45           6.0            128.0
# 31              5500             68           8.0            256.0
# 42              6720             33           8.0            128.0
# ..               ...            ...           ...              ...
# 913             5000             44           6.0            128.0
# 919             5000             25           8.0            128.0
# 939             5000              0           8.0            128.0
# 979             5000             18           8.0            128.0
# 980             5000             44           8.0            128.0
#
#      num_rear_camera    num_front_camera  \
# 14                 2  32 MP Front Camera
# 20                 2  16 MP Front Camera
# 23                 3  20 MP Front Camera
# 31                 2  32 MP Front Camera
# 42                 2  32 MP Front Camera
# ..               ...                 ...
# 913                3  16 MP Front Camera
# 919                4  32 MP Front Camera
# 939                2   8 MP Front Camera
# 979                2   8 MP Front Camera
# 980                2  32 MP Front Camera
#
#                                                display  screen_size  \
# 14   6.7 inches, 1080 x 2400 px, 120 Hz Display wit...         6.70
# 20   6.77 inches, 1080 x 2392 px, 120 Hz Display wi...         6.77
# 23   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...         6.67
# 31   6.7 inches, 1220 x 2712 px, 120 Hz Display wit...         6.70
# 42   6.7 inches, 1220 x 2712 px, 120 Hz Display wit...         6.70
# ..                                                 ...          ...
# 913  6.44 inches, 1080 x 2400 px, 120 Hz Display wi...         6.44
# 919  6.7 inches, 1080 x 2400 px, 120 Hz Display wit...         6.70
# 939                 6.1 inches, 1080 x 2340 px Display         6.10
# 979  6.7 inches, 720 x 1600 px, 120 Hz Display with...         6.70
# 980  6.78 inches, 2400 x 1080 px, 120 Hz Display wi...         6.78
#
#        resolution  refresh_rate  \
# 14   1080 x 2400            120
# 20   1080 x 2392            120
# 23   1080 x 2400            120
# 31   1220 x 2712            120
# 42   1220 x 2712            120
# ..            ...           ...
# 913  1080 x 2400            120
# 919  1080 x 2400            120
# 939  1080 x 2340             60
# 979   720 x 1600            120
# 980  2400 x 1080            120
#
#                                                 camera  \
# 14         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 20         50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 23   50 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 31        50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 42         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# ..                                                 ...
# 913  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 919              108 MP Quad Rear & 32 MP Front Camera
# 939        50 MP + 13 MP Dual Rear & 8 MP Front Camera
# 979  48 MP + Depth Sensor Dual Rear & 8 MP Front Ca...
# 980        50 MP + 2 MP Dual Rear & 32 MP Front Camera
#
#                                 card           os primary_camera_front
# 14   Memory Card (Hybrid), upto 1 TB  Android v15                    3
# 20   Memory Card (Hybrid), upto 1 TB  Android v15                    1
# 23   Memory Card (Hybrid), upto 1 TB  Android v14                    2
# 31   Memory Card (Hybrid), upto 1 TB  Android v15                    3
# 42   Memory Card (Hybrid), upto 1 TB  Android v15                    3
# ..                               ...          ...                  ...
# 913  Memory Card (Hybrid), upto 1 TB  Android v12                    1
# 919  Memory Card (Hybrid), upto 1 TB  Android v12                    3
# 939  Memory Card (Hybrid), upto 1 TB  Android v15                    8
# 979  Memory Card (Hybrid), upto 1 TB  Android v14                    8
# 980  Memory Card (Hybrid), upto 1 TB  Android v14                    3
#
# [111 rows x 30 columns]

# %%
df1.loc[temp_df.index,'card'] = 'Not Specified'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported             592
# Memory Card (Hybrid), upto 1 TB       111
# Memory Card Supported, upto 1 TB       62
# Memory Card (Hybrid), upto 2 TB        57
# Memory Card (Hybrid)                   48
# Memory Card Supported                  45
# Memory Card Supported, upto 2 TB       23
# Not Specified                          22
# Memory Card (Hybrid), upto 1.5 TB       7
# Memory Card Supported, upto 512 GB      6
# Memory Card Supported, upto 128 GB      4
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card Supported, upto 256 GB      1
# Memory Card (Hybrid), upto 1.02 TB      1
# Memory Card Supported, upto 32 GB       1
# Name: count, dtype: int64

# %%
df1['extended_memory'] = (df1['card'].apply(lambda x: '0' if 'Not' in str(x) else str(x).split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported, upto 1 TB', 'Not Specified'))

# %%
df1['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                        614
# 1 TB                     173
# 2 TB                      80
# Memory Card (Hybrid)      48
# Memory Card Supported     45
# 1.5 TB                     7
# 512 GB                     6
# 128 GB                     4
# 256 GB                     3
# 1.02 TB                    1
# 32 GB                      1
# Name: count, dtype: int64

# %%
df1['os'].value_counts()
# Out:
# os
# No FM Radio                                     298
# Android v15                                     265
# Android v14                                     170
# Android v16                                      68
# Bluetooth                                        39
# Android v13                                      36
# Memory Card Not Supported                        16
# Android v12                                      15
# iOS v18                                          13
# Android v11                                       9
# iOS v26                                           8
# Memory Card Supported                             8
# Android v10                                       4
# iOS v17                                           4
# Memory Card (Hybrid), upto 1.5 TB                 3
# Android v9.0 (Pie)                                3
# Memory Card (Hybrid)                              2
# iOS v16                                           2
# Android v17                                       2
# Memory Card (Hybrid), upto 1 TB                   2
# Android v8.1 (Oreo)                               2
# iOS v20                                           1
# HarmonyOS v4.2                                    1
# Memory Card Supported, upto 32 GB                 1
# iOS v15                                           1
# 0.3 MP Rear Camera                                1
# iOS v19                                           1
# Hongmeng OS v5.0                                  1
# HarmonyOS v5                                      1
# Memory Card Supported, upto 1 TB                  1
# Android v12.1                                     1
# 2 MP Rear Camera                                  1
# 50 MP + 50 MP Dual Rear & 32 MP Front Camera      1
# Android v7.0 (Nougat)                             1
# Name: count, dtype: int64

# %%
df1[df1['os'].str.contains('Memory Card', na=False)]
# Out:
#      index brand_name                                        model   price  \
# 119    121     Xiaomi                                Xiaomi 17 Pro   62990
# 149    151     Realme                                Realme 15x 5G   16999
# 203    206       Lava                               Lava Agni 3 5G   16999
# 310    315      Nokia                              Nokia 2780 Flip    4990
# 360    365    Samsung  Samsung Galaxy S25 Ultra (12GB RAM + 512GB)  124999
# 434    441    OnePlus                OnePlus 11 (16GB RAM + 256GB)   39690
# 479    487       Lava             Lava Agni 3 5G (8GB RAM + 256GB)   20999
# 536    546       Lava             Lava Blaze Duo (8GB RAM + 128GB)   14499
# 588    600    Samsung                   Samsung Galaxy Z Flip 4 5G   39999
# 597    610    Infinix                           Infinix Hot 60 Pro   13990
# 600    613    Samsung          Samsung Galaxy M06 (4GB RAM + 64GB)    8999
# 628    642    Samsung                        Samsung Galaxy A16 5G   16200
# 632    646      Nokia                            Nokia 2720 V Flip    6199
# 633    649    Samsung      Samsung Galaxy S25 FE (8GB RAM + 512GB)   77999
# 642    659       Vivo                                Vivo Y19s Pro    9990
# 650    667    Samsung      Samsung Galaxy F06 5G (6GB RAM + 128GB)   11449
# 684    701   Motorola                            Motorola Moto G42    8499
# 720    737      Honor                               Honor Magic V5  107990
# 721    738     Doogee                             Doogee S200 Plus   24990
# 726    743   Motorola                       Motorola Razr 60 Ultra   89998
# 729    747   Motorola                          Motorola Razr 60 5G   48990
# 740    759    Samsung                        Samsung Galaxy F16 5G   12499
# 746    765       Vivo                            Vivo X Fold 3 Pro  159999
# 834    855       Oppo                                  Oppo A56 5G   17990
# 837    860    Ulefone                      Ulefone Armor 29 Pro 5G   86500
# 847    871    Ulefone                       Ulefone Armor 29 Ultra   70990
# 888    915    Samsung         Samsung Galaxy M55 (8GB RAM + 256GB)   21399
# 901    929   Motorola                         Motorola Edge 40 Neo   19900
# 904    933      Cubot                             Cubot KingKong 9   24990
# 937    967     Doogee                              Doogee S200 Max   49999
# 945    975   Motorola                       Motorola Razr 70 Ultra  109990
# 969   1000       Lava                               Lava Blaze Duo   14299
# 983   1017    OnePlus                 OnePlus Open 5G Apex Edition  149998
#
#      rating                                                sim  has_5g  \
# 119    94.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
# 149     NaN                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 203    81.0           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi    True
# 310     NaN                            Dual Sim, 3G, 4G, Wi-Fi   False
# 360    93.0      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True
# 434    88.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 479    82.0           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi    True
# 536     NaN           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi    True
# 588    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 597     NaN    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False
# 600     NaN                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 628    80.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 632     NaN                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 633    87.0      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True
# 642     NaN                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 650     NaN                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 684     NaN                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 720    93.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
# 721    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 726    93.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 729    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 740     NaN            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 746    96.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
# 834     NaN                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 837    96.0       Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC, IR Blaster    True
# 847    96.0       Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC, IR Blaster    True
# 888    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 901    82.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 904    85.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 937    94.0                   Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC    True
# 945    83.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 969     NaN           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi    True
# 983    94.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
#
#      has_nfc  has_ir_blaster  \
# 119     True            True
# 149    False           False
# 203    False           False
# 310    False           False
# 360     True           False
# 434     True           False
# 479    False           False
# 536    False           False
# 588     True           False
# 597     True            True
# 600    False           False
# 628     True           False
# 632    False           False
# 633     True           False
# 642    False           False
# 650    False           False
# 684     True           False
# 720     True            True
# 721     True           False
# 726     True           False
# 729     True           False
# 740     True           False
# 746     True            True
# 834    False           False
# 837     True            True
# 847     True            True
# 888     True           False
# 901     True           False
# 904     True           False
# 937     True           False
# 945     True           False
# 969    False           False
# 983     True            True
#
#                                              processor  \
# 119  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 149       Dimensity 6300, Octa Core, 2.4 GHz Processor
# 203      Dimensity 7300X, Octa Core, 2.5 GHz Processor
# 310     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 360  Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 434    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 479      Dimensity 7300X, Octa Core, 2.5 GHz Processor
# 536       Dimensity 7025, Octa Core, 2.5 GHz Processor
# 588  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 597           Helio G200, Octa Core, 2.2 GHz Processor
# 600       Dimensity 6300, Octa Core, 2.4 GHz Processor
# 628       Dimensity 6300, Octa Core, 2.4 GHz Processor
# 632      Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 633          Exynos 2400, Deca Core, 3.2 GHz Processor
# 642          Unisoc T612, Octa Core, 1.8 GHz Processor
# 650       Dimensity 6300, Octa Core, 2.4 GHz Processor
# 684       Snapdragon 680, Octa Core, 2.4 GHz Processor
# 720  Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor
# 721       Dimensity 7300, Octa Core, 2.5 GHz Processor
# 726  Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor
# 729      Dimensity 7400X, Octa Core, 2.6 GHz Processor
# 740       Dimensity 6300, Octa Core, 2.4 GHz Processor
# 746    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 834     Dimensity 700 5G, Octa Core, 2.2 GHz Processor
# 837       Dimensity 7400, Octa Core, 2.6 GHz Processor
# 847  Dimensity 9300 Plus, Octa Core, 3.25 GHz Proce...
# 888    Snapdragon 7 Gen1, Octa Core, 2.4 GHz Processor
# 901       Dimensity 7030, Octa Core, 2.5 GHz Processor
# 904            Helio G99, Octa Core, 2.2 GHz Processor
# 937       Dimensity 7050, Octa Core, 2.6 GHz Processor
# 945      Snapdragon 8 Elite Gen 5, Octa Core Processor
# 969       Dimensity 7025, Octa Core, 2.5 GHz Processor
# 983    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                     processor_name processor_brand  num_cores  \
# 119       Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 149                 Dimensity 6300       dimensity  Octa Core
# 203                Dimensity 7300X       dimensity  Octa Core
# 310               Snapdragon QM215      snapdragon  Quad Core
# 360  Snapdragon 8 Elite for Galaxy      snapdragon  Octa Core
# 434              Snapdragon 8 Gen2      snapdragon  Octa Core
# 479                Dimensity 7300X       dimensity  Octa Core
# 536                 Dimensity 7025       dimensity  Octa Core
# 588            Snapdragon  8+ Gen1      snapdragon  Octa Core
# 597                     Helio G200           helio  Octa Core
# 600                 Dimensity 6300       dimensity  Octa Core
# 628                 Dimensity 6300       dimensity  Octa Core
# 632                 Snapdragon 205      snapdragon  Dual Core
# 633                    Exynos 2400          exynos  Deca Core
# 642                    Unisoc T612          unisoc  Octa Core
# 650                 Dimensity 6300       dimensity  Octa Core
# 684                 Snapdragon 680      snapdragon  Octa Core
# 720             Snapdragon 8 Elite      snapdragon  Octa Core
# 721                 Dimensity 7300       dimensity  Octa Core
# 726             Snapdragon 8 Elite      snapdragon  Octa Core
# 729                Dimensity 7400X       dimensity  Octa Core
# 740                 Dimensity 6300       dimensity  Octa Core
# 746              Snapdragon 8 Gen3      snapdragon  Octa Core
# 834               Dimensity 700 5G       dimensity  Octa Core
# 837                 Dimensity 7400       dimensity  Octa Core
# 847            Dimensity 9300 Plus       dimensity  Octa Core
# 888              Snapdragon 7 Gen1      snapdragon  Octa Core
# 901                 Dimensity 7030       dimensity  Octa Core
# 904                      Helio G99           helio  Octa Core
# 937                 Dimensity 7050       dimensity  Octa Core
# 945       Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 969                 Dimensity 7025       dimensity  Octa Core
# 983              Snapdragon 8 Gen2      snapdragon  Octa Core
#
#      processor_speed                        ram  \
# 119             4.60  12 GB RAM, 256 GB inbuilt
# 149             2.40   6 GB RAM, 128 GB inbuilt
# 203             2.50   8 GB RAM, 128 GB inbuilt
# 310             1.30   512 MB RAM, 4 GB inbuilt
# 360             4.47  12 GB RAM, 512 GB inbuilt
# 434             3.20  16 GB RAM, 256 GB inbuilt
# 479             2.50   8 GB RAM, 256 GB inbuilt
# 536             2.50   8 GB RAM, 128 GB inbuilt
# 588             3.20   8 GB RAM, 128 GB inbuilt
# 597             2.20   8 GB RAM, 128 GB inbuilt
# 600             2.40    4 GB RAM, 64 GB inbuilt
# 628             2.40   8 GB RAM, 128 GB inbuilt
# 632             1.10   512 MB RAM, 4 GB inbuilt
# 633             3.20   8 GB RAM, 512 GB inbuilt
# 642             1.80   6 GB RAM, 128 GB inbuilt
# 650             2.40   6 GB RAM, 128 GB inbuilt
# 684             2.40    4 GB RAM, 64 GB inbuilt
# 720             4.32  12 GB RAM, 256 GB inbuilt
# 721             2.50  12 GB RAM, 512 GB inbuilt
# 726             4.32  16 GB RAM, 512 GB inbuilt
# 729             2.60   8 GB RAM, 256 GB inbuilt
# 740             2.40   4 GB RAM, 128 GB inbuilt
# 746             3.30  16 GB RAM, 512 GB inbuilt
# 834             2.20   6 GB RAM, 128 GB inbuilt
# 837             2.60  16 GB RAM, 512 GB inbuilt
# 847             3.25    16 GB RAM, 1 TB inbuilt
# 888             2.40   8 GB RAM, 256 GB inbuilt
# 901             2.50   8 GB RAM, 128 GB inbuilt
# 904             2.20  12 GB RAM, 256 GB inbuilt
# 937             2.60  16 GB RAM, 512 GB inbuilt
# 945              NaN  16 GB RAM, 512 GB inbuilt
# 969             2.50   6 GB RAM, 128 GB inbuilt
# 983             3.20    16 GB RAM, 1 TB inbuilt
#
#                                        battery battery_capacity  \
# 119   6300 mAh Battery with 100W Fast Charging             6300
# 149                                        NaN              NaN
# 203    5000 mAh Battery with 66W Fast Charging             5000
# 310                           1450 mAh Battery             1450
# 360                                        NaN              NaN
# 434                                        NaN              NaN
# 479    5000 mAh Battery with 66W Fast Charging             5000
# 536    5000 mAh Battery with 33W Fast Charging             5000
# 588    3700 mAh Battery with 25W Fast Charging             3700
# 597                                        NaN              NaN
# 600                                        NaN              NaN
# 628                                        NaN              NaN
# 632                           1500 mAh Battery             1500
# 633                                        NaN              NaN
# 642                                        NaN              NaN
# 650                                        NaN              NaN
# 684                                        NaN              NaN
# 720    5820 mAh Battery with 66W Fast Charging             5820
# 721   10100 mAh Battery with 33W Fast Charging            10100
# 726    4700 mAh Battery with 68W Fast Charging             4700
# 729    4500 mAh Battery with 30W Fast Charging             4500
# 740                                        NaN              NaN
# 746   5700 mAh Battery with 100W Fast Charging             5700
# 834                                        NaN              NaN
# 837  21200 mAh Battery with 120W Fast Charging            21200
# 847  21200 mAh Battery with 120W Fast Charging            21200
# 888                                        NaN              NaN
# 901                                        NaN              NaN
# 904   10600 mAh Battery with 33W Fast Charging            10600
# 937   22000 mAh Battery with 66W Fast Charging            22000
# 945    5100 mAh Battery with 80W Fast Charging             5100
# 969    5000 mAh Battery with 33W Fast Charging             5000
# 983    4805 mAh Battery with 67W Fast Charging             4805
#
#      fast_charging  ram_capacity  internal_memory  num_rear_camera  \
# 119            100          12.0            256.0                2
# 149             -1           6.0            128.0                2
# 203             66           8.0            128.0                2
# 310             -1         512.0              4.0                2
# 360             -1          12.0            512.0                4
# 434             -1          16.0            256.0                3
# 479             66           8.0            256.0                2
# 536             33           8.0            128.0                2
# 588             25           8.0            128.0                2
# 597             -1           8.0            128.0                1
# 600             -1           4.0             64.0                2
# 628             -1           8.0            128.0                3
# 632             -1         512.0              4.0                2
# 633             -1           8.0            512.0                3
# 642             -1           6.0            128.0                1
# 650             -1           6.0            128.0                2
# 684             -1           4.0             64.0                1
# 720             66          12.0            256.0                2
# 721             33          12.0            512.0                2
# 726             68          16.0            512.0                2
# 729             30           8.0            256.0                2
# 740             -1           4.0            128.0                3
# 746            100          16.0            512.0                2
# 834             -1           6.0            128.0                2
# 837            120          16.0            512.0                2
# 847            120          16.0           1024.0                2
# 888             -1           8.0            256.0                3
# 901             -1           8.0            128.0                2
# 904             33          12.0            256.0                2
# 937             66          16.0            512.0                2
# 945             80          16.0            512.0                2
# 969             33           6.0            128.0                2
# 983             67          16.0           1024.0                2
#
#        num_front_camera                                            display  \
# 119                 NaN  6.3 inches, 1220 x 2656 px, 144 Hz Display wit...
# 149  50 MP Front Camera            7000 mAh Battery with 60W Fast Charging
# 203                 NaN  6.78 inches, 1200 x 2652 px, 120 Hz Display wi...
# 310                 NaN                   2.7 inches, 240 x 320 px Display
# 360  12 MP Front Camera            5000 mAh Battery with 45W Fast Charging
# 434  16 MP Front Camera           5000 mAh Battery with 100W Fast Charging
# 479                 NaN  6.78 inches, 1200 x 2652 px, 120 Hz Display wi...
# 536                 NaN  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 588                 NaN  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 597  13 MP Front Camera            5160 mAh Battery with 45W Fast Charging
# 600   8 MP Front Camera            5000 mAh Battery with 25W Fast Charging
# 628  13 MP Front Camera            5000 mAh Battery with 25W Fast Charging
# 632                 NaN                   2.8 inches, 240 x 320 px Display
# 633  12 MP Front Camera            4900 mAh Battery with 45W Fast Charging
# 642   5 MP Front Camera            6000 mAh Battery with 44W Fast Charging
# 650   8 MP Front Camera            5000 mAh Battery with 25W Fast Charging
# 684                 NaN            5000 mAh Battery with 20W Fast Charging
# 720                 NaN  7.95 inches, 2172 x 2352 px, 120 Hz Display wi...
# 721                 NaN  6.72 inches, 1080 x 2400 px, 120 Hz Display wi...
# 726                 NaN  6.96 inches, 1224 x 2992 px, 165 Hz Display wi...
# 729                 NaN  6.9 inches, 1080 x 2640 px, 120 Hz Display wit...
# 740  13 MP Front Camera            5000 mAh Battery with 25W Fast Charging
# 746                 NaN  8.03 inches, 2200 x 2480 px, 120 Hz Display wi...
# 834   8 MP Front Camera                                   5000 mAh Battery
# 837                 NaN                6.67 inches, 1080 x 2400 px Display
# 847                 NaN  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 888  50 MP Front Camera            5000 mAh Battery with 45W Fast Charging
# 901  32 MP Front Camera            5000 mAh Battery with 68W Fast Charging
# 904                 NaN  6.58 inches, 1080 x 2408 px, 120 Hz Display wi...
# 937                 NaN  6.72 inches, 1080 x 2400 px Display with Water...
# 945                 NaN  7.1 inches, 1224 x 2992 px, 165 Hz Display wit...
# 969                 NaN  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 983                 NaN  7.82 inches, 2268 x 2440 px, 120 Hz Display wi...
#
#      screen_size    resolution  refresh_rate  \
# 119         6.30  1220 x 2656            144
# 149      7000.00           NaN            60
# 203         6.78  1200 x 2652            120
# 310         2.70    240 x 320             60
# 360      5000.00           NaN            60
# 434      5000.00           NaN            60
# 479         6.78  1200 x 2652            120
# 536         6.67  1080 x 2400            120
# 588         6.70  1080 x 2640            120
# 597      5160.00           NaN            60
# 600      5000.00           NaN            60
# 628      5000.00           NaN            60
# 632         2.80    240 x 320             60
# 633      4900.00           NaN            60
# 642      6000.00           NaN            60
# 650      5000.00           NaN            60
# 684      5000.00           NaN            60
# 720         7.95  2172 x 2352            120
# 721         6.72  1080 x 2400            120
# 726         6.96  1224 x 2992            165
# 729         6.90  1080 x 2640            120
# 740      5000.00           NaN            60
# 746         8.03  2200 x 2480            120
# 834      5000.00           NaN            60
# 837         6.67  1080 x 2400             60
# 847         6.67  1080 x 2400            120
# 888      5000.00           NaN            60
# 901      5000.00           NaN            60
# 904         6.58  1080 x 2408            120
# 937         6.72  1080 x 2400             60
# 945         7.10  1224 x 2992            165
# 969         6.67  1080 x 2400            120
# 983         7.82  2268 x 2440            120
#
#                                                 camera  \
# 119                                       Dual Display
# 149        50 MP + 2 MP Dual Rear & 50 MP Front Camera
# 203                                       Dual Display
# 310                                       Dual Display
# 360              200 MP Quad Rear & 12 MP Front Camera
# 434  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 479                                       Dual Display
# 536                                       Dual Display
# 588                                              50 MP
# 597                    50 MP Rear & 13 MP Front Camera
# 600         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 628  50 MP + 5 MP + 2 MP Triple Rear & 13 MP Front ...
# 632                                       Dual Display
# 633  50 MP + 12 MP + 8 MP Triple Rear & 12 MP Front...
# 642                     50 MP Rear & 5 MP Front Camera
# 650         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 684  6.47 inches, 1080 x 2400 px Display with Punch...
# 720                                              50 MP
# 721                                       Dual Display
# 726                                              50 MP
# 729                                              50 MP
# 740  50 MP + 5 MP + 2 MP Triple Rear & 13 MP Front ...
# 746                                              50 MP
# 834         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 837                                       Dual Display
# 847                                       Dual Display
# 888  50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 901       50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 904                                       Dual Display
# 937                                       Dual Display
# 945                                              50 MP
# 969                                       Dual Display
# 983                                              50 MP
#
#                           card                                 os  \
# 119  Memory Card Not Supported          Memory Card Not Supported
# 149  Memory Card Not Supported               Memory Card (Hybrid)
# 203  Memory Card Not Supported          Memory Card Not Supported
# 310  Memory Card Not Supported  Memory Card Supported, upto 32 GB
# 360  Memory Card Not Supported          Memory Card Not Supported
# 434  Memory Card Not Supported          Memory Card Not Supported
# 479  Memory Card Not Supported          Memory Card Not Supported
# 536  Memory Card Not Supported          Memory Card Not Supported
# 588              Not Specified          Memory Card Not Supported
# 597  Memory Card Not Supported              Memory Card Supported
# 600  Memory Card Not Supported  Memory Card (Hybrid), upto 1.5 TB
# 628  Memory Card Not Supported  Memory Card (Hybrid), upto 1.5 TB
# 632  Memory Card Not Supported              Memory Card Supported
# 633  Memory Card Not Supported          Memory Card Not Supported
# 642  Memory Card Not Supported              Memory Card Supported
# 650  Memory Card Not Supported    Memory Card (Hybrid), upto 1 TB
# 684  Memory Card Not Supported   Memory Card Supported, upto 1 TB
# 720              Not Specified          Memory Card Not Supported
# 721  Memory Card Not Supported              Memory Card Supported
# 726              Not Specified          Memory Card Not Supported
# 729              Not Specified          Memory Card Not Supported
# 740  Memory Card Not Supported  Memory Card (Hybrid), upto 1.5 TB
# 746              Not Specified          Memory Card Not Supported
# 834  Memory Card Not Supported              Memory Card Supported
# 837  Memory Card Not Supported              Memory Card Supported
# 847  Memory Card Not Supported              Memory Card Supported
# 888  Memory Card Not Supported    Memory Card (Hybrid), upto 1 TB
# 901  Memory Card Not Supported          Memory Card Not Supported
# 904  Memory Card Not Supported               Memory Card (Hybrid)
# 937  Memory Card Not Supported              Memory Card Supported
# 945              Not Specified          Memory Card Not Supported
# 969  Memory Card Not Supported          Memory Card Not Supported
# 983              Not Specified          Memory Card Not Supported
#
#     primary_camera_front extended_memory
# 119                  NaN               0
# 149                    5               0
# 203                  NaN               0
# 310                  NaN               0
# 360                    1               0
# 434                    1               0
# 479                  NaN               0
# 536                  NaN               0
# 588                  NaN               0
# 597                    1               0
# 600                    8               0
# 628                    1               0
# 632                  NaN               0
# 633                    1               0
# 642                    5               0
# 650                    8               0
# 684                  NaN               0
# 720                  NaN               0
# 721                  NaN               0
# 726                  NaN               0
# 729                  NaN               0
# 740                    1               0
# 746                  NaN               0
# 834                    8               0
# 837                  NaN               0
# 847                  NaN               0
# 888                    5               0
# 901                    3               0
# 904                  NaN               0
# 937                  NaN               0
# 945                  NaN               0
# 969                  NaN               0
# 983                  NaN               0

# %%
df1.loc[temp_df.index,'os'] = 'Not Specified'

# %%
df1['os'].value_counts()
# Out:
# os
# No FM Radio                          298
# Android v15                          264
# Android v14                          167
# Android v16                           62
# Bluetooth                             39
# Android v13                           35
# Not Specified                         22
# Android v12                           15
# iOS v18                               13
# Android v11                            9
# Memory Card Not Supported              9
# iOS v26                                8
# Memory Card Supported                  8
# Android v10                            4
# iOS v17                                4
# Android v9.0 (Pie)                     3
# Memory Card (Hybrid), upto 1.5 TB      3
# iOS v16                                2
# Android v8.1 (Oreo)                    2
# Memory Card (Hybrid)                   2
# Memory Card (Hybrid), upto 1 TB        2
# Memory Card Supported, upto 32 GB      1
# iOS v15                                1
# iOS v20                                1
# 0.3 MP Rear Camera                     1
# Android v17                            1
# Hongmeng OS v5.0                       1
# iOS v19                                1
# Memory Card Supported, upto 1 TB       1
# Android v12.1                          1
# 2 MP Rear Camera                       1
# Android v7.0 (Nougat)                  1
# Name: count, dtype: int64

# %%
def os_extractor(text):

  if 'Android' in text:
    return 'android'
  elif 'iOS' in text:
    return 'ios'
  elif 'Not Specified':
    return text
  elif 'Harmony' in text or 'Hongmeng' in text or 'EMUI' in text:
    return 'other'

# %%
df1['os'] = df1['os'].apply(os_extractor)

# %%
df1.head()
# Out:
#    index brand_name                     model  price  rating  \
# 0      2       OPPO           OPPO Reno 15 5G  39990    90.0
# 1      3    Samsung  Samsung Galaxy S24 Ultra  84999    92.0
# 2      4       iQOO                   iQOO 15  67999    91.0
# 3      5     Realme           Realme GT 8 Pro  72999    94.0
# 4      6     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0
#
#                                                  sim  has_5g  has_nfc  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC    True     True
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...    True     True
#
#    has_ir_blaster                                          processor  \
# 0            True      Dimensity 8450, Octa Core, 3.25 GHz Processor
# 1           False    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 3            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
# 4            True  Snapdragon 8 Elite Gen 5, Octa Core, 4.6 GHz P...
#
#              processor_name processor_brand  num_cores  processor_speed  \
# 0            Dimensity 8450       dimensity  Octa Core             3.25
# 1         Snapdragon 8 Gen3      snapdragon  Octa Core             3.30
# 2  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 3  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
# 4  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core             4.60
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 80W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 100W Fast Charging
# 3  12 GB RAM, 256 GB inbuilt  7000 mAh Battery with 120W Fast Charging
# 4  12 GB RAM, 256 GB inbuilt  7500 mAh Battery with 100W Fast Charging
#
#   battery_capacity  fast_charging  ram_capacity  internal_memory  \
# 0             6200             80          12.0            256.0
# 1             5000             45          12.0            256.0
# 2             7000            100          12.0            256.0
# 3             7000            120          12.0            256.0
# 4             7500            100          12.0            256.0
#
#    num_rear_camera    num_front_camera  \
# 0                3  50 MP Front Camera
# 1                4  12 MP Front Camera
# 2                3  32 MP Front Camera
# 3                3  32 MP Front Camera
# 4                3  32 MP Front Camera
#
#                                              display  screen_size  \
# 0  6.32 inches, 1216 x 2640 px, 120 Hz Display wi...         6.32
# 1  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...         6.80
# 2  6.85 inches, 1440 x 3168 px, 144 Hz Display wi...         6.85
# 3  6.79 inches, 1440 x 3136 px, 144 Hz Display wi...         6.79
# 4  6.9 inches, 1200 x 2608 px, 120 Hz Display wit...         6.90
#
#      resolution  refresh_rate  \
# 0  1216 x 2640            120
# 1  1440 x 3120            120
# 2  1440 x 3168            144
# 3  1440 x 3136            144
# 4  1200 x 2608            120
#
#                                               camera  \
# 0  200 MP + 50 MP + 50 MP Triple Rear & 50 MP Fro...
# 1              200 MP Quad Rear & 12 MP Front Camera
# 2  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 3  200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 4  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
#
#                         card           os primary_camera_front extended_memory
# 0  Memory Card Not Supported  No FM Radio                    5               0
# 1  Memory Card Not Supported      android                    1               0
# 2  Memory Card Not Supported  No FM Radio                    3               0
# 3  Memory Card Not Supported      android                    3               0
# 4  Memory Card Not Supported  No FM Radio                    3               0

# %%
export_df = df1.drop(columns=['index','sim','processor','ram','battery','display','camera','card',])
export_df.to_csv('smartphone_cleaned_v2.csv',index=False)
