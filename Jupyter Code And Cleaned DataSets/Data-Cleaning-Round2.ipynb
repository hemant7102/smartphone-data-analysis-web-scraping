# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('smartphone_cleaned_v2.csv')

# %%
df.head()
# Out:
#   brand_name                     model  price  rating  has_5g  has_nfc  \
# 0       OPPO           OPPO Reno 15 5G  39990    90.0    True     True
# 1    Samsung  Samsung Galaxy S24 Ultra  84999    92.0    True     True
# 2       iQOO                   iQOO 15  67999    91.0    True     True
# 3     Realme           Realme GT 8 Pro  72999    94.0    True     True
# 4     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True
#
#    has_ir_blaster            processor_name processor_brand  num_cores  \
# 0            True            Dimensity 8450       dimensity  Octa Core
# 1           False         Snapdragon 8 Gen3      snapdragon  Octa Core
# 2            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 3            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 4            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
#
#    processor_speed  battery_capacity  fast_charging  ram_capacity  \
# 0             3.25            6200.0             80          12.0
# 1             3.30            5000.0             45          12.0
# 2             4.60            7000.0            100          12.0
# 3             4.60            7000.0            120          12.0
# 4             4.60            7500.0            100          12.0
#
#    internal_memory  num_rear_camera    num_front_camera  screen_size  \
# 0            256.0                3  50 MP Front Camera         6.32
# 1            256.0                4  12 MP Front Camera         6.80
# 2            256.0                3  32 MP Front Camera         6.85
# 3            256.0                3  32 MP Front Camera         6.79
# 4            256.0                3  32 MP Front Camera         6.90
#
#      resolution  refresh_rate           os primary_camera_front  \
# 0  1216 x 2640            120  No FM Radio                    5
# 1  1440 x 3120            120      android                    1
# 2  1440 x 3168            144  No FM Radio                    3
# 3  1440 x 3136            144      android                    3
# 4  1200 x 2608            120  No FM Radio                    3
#
#   extended_memory
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
df.shape
# Out:
# (982, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            982 non-null    object
#  1   model                 982 non-null    object
#  2   price                 982 non-null    int64
#  3   rating                601 non-null    float64
#  4   has_5g                982 non-null    bool
#  5   has_nfc               982 non-null    bool
#  6   has_ir_blaster        982 non-null    bool
#  7   processor_name        982 non-null    object
#  8   processor_brand       982 non-null    object
#  9   num_cores             921 non-null    object
#  10  processor_speed       836 non-null    float64
#  11  battery_capacity      956 non-null    float64
#  12  fast_charging         982 non-null    int64
#  13  ram_capacity          980 non-null    float64
#  14  internal_memory       975 non-null    float64
#  15  num_rear_camera       982 non-null    int64
#  16  num_front_camera      926 non-null    object
#  17  screen_size           981 non-null    float64
#  18  resolution            948 non-null    object
#  19  refresh_rate          982 non-null    int64
#  20  os                    982 non-null    object
#  21  primary_camera_front  926 non-null    object
#  22  extended_memory       982 non-null    object
# dtypes: bool(3), float64(6), int64(4), object(10)
# memory usage: 156.4+ KB

# %% [markdown]
# ## Working with brand_name Col

# %%
df['brand_name'].value_counts()
# Out:
# brand_name
# Samsung      128
# Vivo         128
# Realme       106
# Xiaomi        70
# Motorola      62
# Oppo          52
# OnePlus       50
# iQOO          44
# Poco          38
# Infinix       36
# Apple         33
# OPPO          31
# Tecno         28
# Lava          25
# Honor         23
# Google        20
# Nothing       18
# Nubia         11
# Nokia          9
# Peace          6
# itel           5
# CMF            5
# HMD            5
# Huawei         5
# Ai+            4
# Asus           4
# Oneplus        3
# Jio            2
# Doogee         2
# Alcatel        2
# Oukitel        2
# Vertu          2
# Sony           2
# POCO           2
# Light          2
# Ulefone        2
# RedMagic       1
# Wobble         1
# Red            1
# Tesla          1
# Unihertz       1
# Bluefox        1
# MTR            1
# LAVA           1
# ZTE            1
# iKall          1
# Redmi          1
# Acer           1
# Energizer      1
# Cubot          1
# Micromax       1
# Name: count, dtype: int64

# %% [markdown]
# ## top 10 phone brands

# %%
df['brand_name'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand_name'>

# %% [markdown]
# ## price col

# %%
df['price'].describe()
# Out:
# count       982.000000
# mean      36762.934827
# std       41316.272266
# min        3499.000000
# 25%       15169.250000
# 50%       23999.000000
# 75%       40742.250000
# max      489990.000000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df['price'].skew()
# Out:
# np.float64(4.766547724943288)

# %%
sns.boxplot(df[df['price']<200000]['price'])
# Out:
# <Axes: ylabel='price'>

# %%
df[df['price']>200000]
# Out:
#     brand_name                                     model   price  rating  \
# 273    Samsung  Samsung Galaxy Z Fold 7 (16GB RAM + 1TB)  216999    97.0
# 457     Huawei                   Huawei Mate XT Ultimate  235990    83.0
# 504      Vertu                            Vertu Ironflip  489990    84.0
# 811      Vertu                         Vertu Metavertu 2  425999    86.0
# 925     Xiaomi    Xiaomi Redmi K20 Pro Signature Edition  480000    86.0
#
#      has_5g  has_nfc  has_ir_blaster                 processor_name  \
# 273    True     True           False  Snapdragon 8 Elite for Galaxy
# 457    True     True            True            Octa Core Processor
# 504    True     True           False              Snapdragon 8 Gen2
# 811    True     True           False              Snapdragon 8 Gen2
# 925   False     True           False                Snapdragon  855
#
#     processor_brand  num_cores  processor_speed  battery_capacity  \
# 273      snapdragon  Octa Core             4.47            4400.0
# 457            octa        NaN              NaN            5600.0
# 504      snapdragon  Octa Core             3.20            4310.0
# 811      snapdragon  Octa Core             3.20            5100.0
# 925      snapdragon  Octa Core             2.80            4000.0
#
#      fast_charging  ram_capacity  internal_memory  num_rear_camera  \
# 273             25          16.0           1024.0                2
# 457             66          16.0            256.0                2
# 504             65          12.0            256.0                2
# 811             65          12.0            512.0                3
# 925             27           8.0            256.0                3
#
#        num_front_camera  screen_size    resolution  refresh_rate  \
# 273                 NaN         8.00  1968 x 2184            120
# 457                 NaN        10.20  2232 x 3184            120
# 504                 NaN         6.70  2790 x 1188            120
# 811  16 MP Front Camera         6.78  1260 x 2800            120
# 925  20 MP Front Camera         6.39  1080 x 2340             60
#
#                 os primary_camera_front extended_memory
# 273  Not Specified                  NaN               0
# 457  Not Specified                  NaN               0
# 504        android                  NaN               0
# 811        android                    1               0
# 925        android                    2               0

# %%
df['price'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## rating col

# %%
df['rating'].describe()
# Out:
# count    601.000000
# mean      85.183028
# std        3.879834
# min       80.000000
# 25%       82.000000
# 50%       84.000000
# 75%       87.000000
# max       97.000000
# Name: rating, dtype: float64

# %%
sns.histplot(df['rating'],kde=True)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
df['rating'].skew()
# Out:
# np.float64(0.7579857188406607)

# %%
sns.boxplot(df['rating'])
# Out:
# <Axes: ylabel='rating'>

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(381)

# %%
sns.countplot(df['has_5g'])
# Out:
# <Axes: ylabel='count'>

# %%
df['has_5g'].value_counts()
# Out:
# has_5g
# True     884
# False     98
# Name: count, dtype: int64

# %%
sns.countplot(df['has_nfc'])
# Out:
# <Axes: ylabel='count'>

# %%
df['has_nfc'].value_counts()
# Out:
# has_nfc
# True     557
# False    425
# Name: count, dtype: int64

# %%
sns.countplot(df['has_ir_blaster'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Working with Processor brand Col

# %%
df['processor_brand'] = df['processor_brand'].str.replace('sanpdragon','snapdragon')
df['processor_brand'] = df['processor_brand'].str.replace('apple','bionic')
df['processor_brand'] = df['processor_brand'].str.replace('samsung','exynos')

# %%
temp_df = df[df['processor_brand'] == 'qualcomm']

# %%
df.loc[temp_df.index, 'processor_brand'] = 'snapdragon'

# %%
temp_df = df[df['processor_brand'] == 'a13']

# %%
df.loc[temp_df.index, 'processor_brand'] = 'bionic'

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    371
# dimensity     360
# octa           56
# exynos         51
# helio          42
# unisoc         42
# bionic         31
# tensor         17
# google          3
# no              2
# quad            2
# kirin           1
# 256             1
# tiger           1
# mediatek        1
# 4               1
# Name: count, dtype: int64

# %%
df[df['processor_brand'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_name, processor_brand, num_cores, processor_speed, battery_capacity, fast_charging, ram_capacity, internal_memory, num_rear_camera, num_front_camera, screen_size, resolution, refresh_rate, os, primary_camera_front, extended_memory]
# Index: []

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core              861
# Hexa Core               30
# Deca Core                8
# Single Core              5
# Quad Core                4
# 2 GHz Processor          2
# 512 MHz Processor        1
# Deca Core Processor      1
# Nine-Cores               1
# Nine Cores               1
# 2.5 GHz Processor        1
# Nine Core                1
# Dual Core                1
# 1.3 GHz Processor        1
# 1.4 GHz Processor        1
# 1.6 GHz Processor        1
# 64 GB inbuilt            1
# Name: count, dtype: int64

# %%
df['processor_speed'].describe()
# Out:
# count    836.000000
# mean       2.788337
# std        0.689657
# min        1.100000
# 25%        2.400000
# 50%        2.500000
# 75%        3.200000
# max        4.600000
# Name: processor_speed, dtype: float64

# %%
sns.displot(kind='kde',data=df,x='processor_speed')

# %%
df['processor_speed'].skew()
# Out:
# np.float64(0.9701715483771534)

# %%
sns.boxplot(df['processor_speed'])
# Out:
# <Axes: ylabel='processor_speed'>

# %%
df
# Out:
#     brand_name                                  model   price  rating  has_5g  \
# 0         OPPO                        OPPO Reno 15 5G   39990    90.0    True
# 1      Samsung               Samsung Galaxy S24 Ultra   84999    92.0    True
# 2         iQOO                                iQOO 15   67999    91.0    True
# 3       Realme                        Realme GT 8 Pro   72999    94.0    True
# 4       Xiaomi               Xiaomi Redmi K90 Pro Max   50990    91.0    True
# ..         ...                                    ...     ...     ...     ...
# 977    Infinix  Infinix Hot 50 5G (8 GB RAM + 128 GB)   10999     NaN    True
# 978       Vivo                         Vivo Y300 Plus   23999    80.0    True
# 979       Oppo                        Oppo A3 5G 2024   13999     NaN    True
# 980     Realme                          Realme C63 5G   10990     NaN    True
# 981    OnePlus           OnePlus Open 5G Apex Edition  149998    94.0    True
#
#      has_nfc  has_ir_blaster            processor_name processor_brand  \
# 0       True            True            Dimensity 8450       dimensity
# 1       True           False         Snapdragon 8 Gen3      snapdragon
# 2       True            True  Snapdragon 8 Elite Gen 5      snapdragon
# 3       True            True  Snapdragon 8 Elite Gen 5      snapdragon
# 4       True            True  Snapdragon 8 Elite Gen 5      snapdragon
# ..       ...             ...                       ...             ...
# 977    False           False            Dimensity 6300       dimensity
# 978    False           False            Snapdragon 695      snapdragon
# 979    False           False            Dimensity 6300       dimensity
# 980    False           False            Dimensity 6300       dimensity
# 981     True            True         Snapdragon 8 Gen2      snapdragon
#
#      num_cores  processor_speed  battery_capacity  fast_charging  \
# 0    Octa Core             3.25            6200.0             80
# 1    Octa Core             3.30            5000.0             45
# 2    Octa Core             4.60            7000.0            100
# 3    Octa Core             4.60            7000.0            120
# 4    Octa Core             4.60            7500.0            100
# ..         ...              ...               ...            ...
# 977  Octa Core             2.40            5000.0             18
# 978  Octa Core             2.20            5000.0             44
# 979  Octa Core             2.40            5100.0             45
# 980  Octa Core             2.40            5000.0             10
# 981  Octa Core             3.20            4805.0             67
#
#      ram_capacity  internal_memory  num_rear_camera    num_front_camera  \
# 0            12.0            256.0                3  50 MP Front Camera
# 1            12.0            256.0                4  12 MP Front Camera
# 2            12.0            256.0                3  32 MP Front Camera
# 3            12.0            256.0                3  32 MP Front Camera
# 4            12.0            256.0                3  32 MP Front Camera
# ..            ...              ...              ...                 ...
# 977           8.0            128.0                2   8 MP Front Camera
# 978           8.0            128.0                2  32 MP Front Camera
# 979           6.0            128.0                2   5 MP Front Camera
# 980           4.0            128.0                2   8 MP Front Camera
# 981          16.0           1024.0                2                 NaN
#
#      screen_size    resolution  refresh_rate             os  \
# 0           6.32  1216 x 2640            120    No FM Radio
# 1           6.80  1440 x 3120            120        android
# 2           6.85  1440 x 3168            144    No FM Radio
# 3           6.79  1440 x 3136            144        android
# 4           6.90  1200 x 2608            120    No FM Radio
# ..           ...           ...           ...            ...
# 977         6.70   720 x 1600            120        android
# 978         6.78  2400 x 1080            120        android
# 979         6.67   720 x 1604            120        android
# 980         6.67   720 x 1604            120        android
# 981         7.82  2268 x 2440            120  Not Specified
#
#     primary_camera_front extended_memory
# 0                      5               0
# 1                      1               0
# 2                      3               0
# 3                      3               0
# 4                      3               0
# ..                   ...             ...
# 977                    8            1 TB
# 978                    3            1 TB
# 979                    5            2 TB
# 980                    8            2 TB
# 981                  NaN               0
#
# [982 rows x 23 columns]

# %% [markdown]
# ## Battery Capacity

# %%
df['battery_capacity'].describe()
# Out:
# count      956.000000
# mean      5636.404979
# std       1659.722695
# min          6.100000
# 25%       5000.000000
# 50%       5500.000000
# 75%       6010.000000
# max      28000.000000
# Name: battery_capacity, dtype: float64

# %%
sns.displot(kind='kde',data=df,x='battery_capacity')

# %%
df[df['battery_capacity'] > 7000]
# Out:
#     brand_name                     model   price  rating  has_5g  has_nfc  \
# 4       Xiaomi  Xiaomi Redmi K90 Pro Max   50990    91.0    True     True
# 7      OnePlus                OnePlus 15   72999    92.0    True     True
# 10        Oppo       Oppo Find X9 Pro 5G  109999    95.0    True     True
# 11        Poco                   Poco F8   37990     NaN    True     True
# 15         Red          Red Magic 11 Pro   60990    89.0    True     True
# ..         ...                       ...     ...     ...     ...      ...
# 928       Poco           Poco M8 Plus 5G   13999     NaN    True    False
# 935     Doogee           Doogee S200 Max   49999    94.0    True     True
# 939    Oukitel       Oukitel WP55 Pro 5G   27990    89.0    True     True
# 951       Vivo                  Vivo Y40   19999     NaN    True    False
# 956      Honor              Honor GT Pro   41999    88.0    True     True
#
#      has_ir_blaster            processor_name processor_brand  num_cores  \
# 4              True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 7              True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 10             True            Dimensity 9500       dimensity  Octa Core
# 11             True       Snapdragon 8s Elite      snapdragon  Octa Core
# 15             True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# ..              ...                       ...             ...        ...
# 928            True        Snapdragon 6s Gen4      snapdragon  Octa Core
# 935           False            Dimensity 7050       dimensity  Octa Core
# 939           False            Dimensity 7025       dimensity  Octa Core
# 951           False       Octa Core Processor            octa        NaN
# 956            True        Snapdragon 8 Elite      snapdragon  Octa Core
#
#      processor_speed  battery_capacity  fast_charging  ram_capacity  \
# 4               4.60            7500.0            100          12.0
# 7               4.60            7300.0            120          12.0
# 10              4.21            7500.0             80          16.0
# 11               NaN            7700.0            100          12.0
# 15              4.60            8000.0             80          12.0
# ..               ...               ...            ...           ...
# 928              NaN            7500.0             44           6.0
# 935             2.60           22000.0             66          16.0
# 939             2.50           11000.0             33          16.0
# 951              NaN            7300.0             44           8.0
# 956             4.32            7200.0             90          12.0
#
#      internal_memory  num_rear_camera    num_front_camera  screen_size  \
# 4              256.0                3  32 MP Front Camera         6.90
# 7              256.0                3  32 MP Front Camera         6.78
# 10             512.0                3  50 MP Front Camera         6.78
# 11             256.0                3  32 MP Front Camera         6.78
# 15             256.0                3  16 MP Front Camera         6.85
# ..               ...              ...                 ...          ...
# 928            128.0                2  16 MP Front Camera         6.92
# 935            512.0                2                 NaN         6.72
# 939            512.0                3  32 MP Front Camera         6.60
# 951            128.0                2  32 MP Front Camera         6.68
# 956            256.0                3  50 MP Front Camera         6.78
#
#        resolution  refresh_rate                     os primary_camera_front  \
# 4    1200 x 2608            120            No FM Radio                    3
# 7    1272 x 2772            165                android                    3
# 10   1272 x 2772            120                android                    5
# 11   1220 x 2712            144                android                    3
# 15   1216 x 2688            144                android                    1
# ..            ...           ...                    ...                  ...
# 928  1080 x 2340            144                android                    1
# 935  1080 x 2400             60  Memory Card Supported                  NaN
# 939  1080 x 2408            120                android                    3
# 951   720 x 1608            120                android                    3
# 956  1224 x 2800            144            No FM Radio                    5
#
#            extended_memory
# 4                        0
# 7                        0
# 10                       0
# 11                       0
# 15                       0
# ..                     ...
# 928                   2 TB
# 935                      0
# 939  Memory Card Supported
# 951                      0
# 956                      0
#
# [70 rows x 23 columns]

# %%
df['fast_charging'].describe()
# Out:
# count    982.000000
# mean      53.233198
# std       36.985652
# min       -1.000000
# 25%       25.000000
# 50%       45.000000
# 75%       80.000000
# max      320.000000
# Name: fast_charging, dtype: float64

# %%
def fast(row):

  if row['fast_charging'] == -1:
    return 0
  else:
    return 1

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'processor_brand', 'num_cores',
#        'processor_speed', 'battery_capacity', 'fast_charging', 'ram_capacity',
#        'internal_memory', 'num_rear_camera', 'num_front_camera', 'screen_size',
#        'resolution', 'refresh_rate', 'os', 'primary_camera_front',
#        'extended_memory'],
#       dtype='object')

# %%
x = df.apply(fast,axis=1)
df.insert(12,'fast_charging_available',x)

# %%
df['fast_charging'] = df['fast_charging'].apply(lambda x:np.nan if x == 0 or x == -1 else x)

# %%
df.head()
# Out:
#   brand_name                     model  price  rating  has_5g  has_nfc  \
# 0       OPPO           OPPO Reno 15 5G  39990    90.0    True     True
# 1    Samsung  Samsung Galaxy S24 Ultra  84999    92.0    True     True
# 2       iQOO                   iQOO 15  67999    91.0    True     True
# 3     Realme           Realme GT 8 Pro  72999    94.0    True     True
# 4     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True
#
#    has_ir_blaster            processor_name processor_brand  num_cores  \
# 0            True            Dimensity 8450       dimensity  Octa Core
# 1           False         Snapdragon 8 Gen3      snapdragon  Octa Core
# 2            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 3            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 4            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
#
#    processor_speed  battery_capacity  fast_charging_available  fast_charging  \
# 0             3.25            6200.0                        1           80.0
# 1             3.30            5000.0                        1           45.0
# 2             4.60            7000.0                        1          100.0
# 3             4.60            7000.0                        1          120.0
# 4             4.60            7500.0                        1          100.0
#
#    ram_capacity  internal_memory  num_rear_camera    num_front_camera  \
# 0          12.0            256.0                3  50 MP Front Camera
# 1          12.0            256.0                4  12 MP Front Camera
# 2          12.0            256.0                3  32 MP Front Camera
# 3          12.0            256.0                3  32 MP Front Camera
# 4          12.0            256.0                3  32 MP Front Camera
#
#    screen_size    resolution  refresh_rate           os primary_camera_front  \
# 0         6.32  1216 x 2640            120  No FM Radio                    5
# 1         6.80  1440 x 3120            120      android                    1
# 2         6.85  1440 x 3168            144  No FM Radio                    3
# 3         6.79  1440 x 3136            144      android                    3
# 4         6.90  1200 x 2608            120  No FM Radio                    3
#
#   extended_memory
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
df['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8.0       421
# 12.0      261
# 6.0       110
# 4.0       106
# 16.0       54
# 3.0        10
# 2.0         4
# 24.0        3
# 512.0       3
# 1.0         2
# 256.0       2
# 128.0       1
# 32.0        1
# 7000.0      1
# 5100.0      1
# Name: count, dtype: int64

# %%
temp_df = df[df['internal_memory'].isnull()]

# %%
df.loc[temp_df.index, ['ram_capacity','internal_memory']] = [4, 64]

# %%
df['internal_memory'].value_counts()
# Out:
# internal_memory
# 256.0     407
# 128.0     395
# 512.0      99
# 64.0       55
# 1024.0     11
# 32.0        8
# 4.0         3
# 8.0         2
# 3.0         1
# 12.0        1
# Name: count, dtype: int64

# %%
df['screen_size'].describe()
# Out:
# count     981.000000
# mean      146.561743
# std       865.189419
# min         2.700000
# 25%         6.670000
# 50%         6.720000
# 75%         6.780000
# max      7500.000000
# Name: screen_size, dtype: float64

# %%
sns.displot(kind='kde',data=df,x='screen_size')

# %%
df['screen_size'].skew()
# Out:
# np.float64(6.233611643061646)

# %%
sns.boxplot(df['screen_size'])
# Out:
# <Axes: ylabel='screen_size'>

# %%
df['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                        614
# 1 TB                     173
# 2 TB                      80
# Memory Card (Hybrid)      48
# Memory Card Supported     45
# 1.5 TB                     7
# 512 GB                     6
# 128 GB                     4
# 256 GB                     3
# 1.02 TB                    1
# 32 GB                      1
# Name: count, dtype: int64

# %%
df['extended_memory_available'] = df['extended_memory'].apply(lambda x:0 if x == '0' else 1)

# %%
def extended_extractor(row):

  if row['extended_memory_available'] == 0:
    return np.nan
  else:
    if row['extended_memory'] == '1 TB':
      return 1024
    elif row['extended_memory'] == '512 GB':
      return 512
    elif row['extended_memory'] == '256 GB':
      return 256
    elif row['extended_memory'] == 'Not Specified':
      return np.nan
    elif row['extended_memory'] == 'Memory Card (Hybrid)':
      return np.nan
    elif row['extended_memory'] == '128 GB':
      return 128
    elif row['extended_memory'] == '2 TB':
      return 2048
    elif row['extended_memory'] == '32 GB':
      return 32
    elif row['extended_memory'] == '64 GB':
      return 64
    elif row['extended_memory'] == '1000 GB':
      return 1000

# %%
def extended_extractor(row):

  if row['extended_memory_available'] == 0:
    return np.nan
  else:
    if row['extended_memory'] == 'Not Specified':
      return np.nan
    elif row['extended_memory'] == 'Memory Card (Hybrid)':
      return np.nan
    else:
      return row['extended_memory']

# %%
df['extended_memory']
x = df.apply(extended_extractor,axis=1).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df['extended_memory_available']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 977    1
# 978    1
# 979    1
# 980    1
# 981    0
# Name: extended_memory_available, Length: 982, dtype: int64

# %%
df['extended_upto'] = x

# %%
df['extended_upto'].value_counts()
# Out:
# extended_upto
# 1         173
# 2          80
# Memory     45
# 1.5         7
# 512         6
# 128         4
# 256         3
# 1.02        1
# 32          1
# Name: count, dtype: int64

# %%
def transform(text):

  if text == '1':
    return '1024'
  elif text == '2':
    return '2048'
  elif text == '1000':
    return '1024'
  else:
    return text

# %%
df['extended_upto'] = df['extended_upto'].apply(transform)

# %%
df['os']
# Out:
# 0        No FM Radio
# 1            android
# 2        No FM Radio
# 3            android
# 4        No FM Radio
#            ...
# 977          android
# 978          android
# 979          android
# 980          android
# 981    Not Specified
# Name: os, Length: 982, dtype: object

# %%
def os_transform(text):

  if 'Memory' in text:
    return np.nan
  elif 'android' in text:
    return text
  elif 'ios' in text:
    return text
  else:
    return 'other'

# %%
df['os'] = df['os'].apply(os_transform)

# %%
df.head()
# Out:
#   brand_name                     model  price  rating  has_5g  has_nfc  \
# 0       OPPO           OPPO Reno 15 5G  39990    90.0    True     True
# 1    Samsung  Samsung Galaxy S24 Ultra  84999    92.0    True     True
# 2       iQOO                   iQOO 15  67999    91.0    True     True
# 3     Realme           Realme GT 8 Pro  72999    94.0    True     True
# 4     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True
#
#    has_ir_blaster            processor_name processor_brand  num_cores  \
# 0            True            Dimensity 8450       dimensity  Octa Core
# 1           False         Snapdragon 8 Gen3      snapdragon  Octa Core
# 2            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 3            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
# 4            True  Snapdragon 8 Elite Gen 5      snapdragon  Octa Core
#
#    processor_speed  battery_capacity  fast_charging_available  fast_charging  \
# 0             3.25            6200.0                        1           80.0
# 1             3.30            5000.0                        1           45.0
# 2             4.60            7000.0                        1          100.0
# 3             4.60            7000.0                        1          120.0
# 4             4.60            7500.0                        1          100.0
#
#    ram_capacity  internal_memory  num_rear_camera    num_front_camera  \
# 0          12.0            256.0                3  50 MP Front Camera
# 1          12.0            256.0                4  12 MP Front Camera
# 2          12.0            256.0                3  32 MP Front Camera
# 3          12.0            256.0                3  32 MP Front Camera
# 4          12.0            256.0                3  32 MP Front Camera
#
#    screen_size    resolution  refresh_rate       os primary_camera_front  \
# 0         6.32  1216 x 2640            120    other                    5
# 1         6.80  1440 x 3120            120  android                    1
# 2         6.85  1440 x 3168            144    other                    3
# 3         6.79  1440 x 3136            144  android                    3
# 4         6.90  1200 x 2608            120    other                    3
#
#   extended_memory  extended_memory_available extended_upto
# 0               0                          0           NaN
# 1               0                          0           NaN
# 2               0                          0           NaN
# 3               0                          0           NaN
# 4               0                          0           NaN

# %%
df['extended_upto'].value_counts()
# Out:
# extended_upto
# 1024      173
# 2048       80
# Memory     45
# 1.5         7
# 512         6
# 128         4
# 256         3
# 1.02        1
# 32          1
# Name: count, dtype: int64

# %%
df.drop(columns=['processor_name','extended_memory'],inplace=True)

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       381
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand                0
# num_cores                     61
# processor_speed              146
# battery_capacity              26
# fast_charging_available        0
# fast_charging                108
# ram_capacity                   1
# internal_memory                0
# num_rear_camera                0
# num_front_camera              56
# screen_size                    1
# resolution                    34
# refresh_rate                   0
# os                            26
# primary_camera_front          56
# extended_memory_available      0
# extended_upto                662
# dtype: int64

# %%
df.corr(numeric_only=True)['rating']
# Out:
# price                        0.429117
# rating                       1.000000
# has_5g                       0.120361
# has_nfc                      0.408305
# has_ir_blaster               0.202610
# processor_speed              0.665098
# battery_capacity             0.129234
# fast_charging_available     -0.004889
# fast_charging                0.244272
# ram_capacity                 0.603119
# internal_memory              0.520909
# num_rear_camera              0.301615
# screen_size                  0.021143
# refresh_rate                 0.111747
# extended_memory_available   -0.288132
# Name: rating, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 982 non-null    object
#  1   model                      982 non-null    object
#  2   price                      982 non-null    int64
#  3   rating                     601 non-null    float64
#  4   has_5g                     982 non-null    bool
#  5   has_nfc                    982 non-null    bool
#  6   has_ir_blaster             982 non-null    bool
#  7   processor_brand            982 non-null    object
#  8   num_cores                  921 non-null    object
#  9   processor_speed            836 non-null    float64
#  10  battery_capacity           956 non-null    float64
#  11  fast_charging_available    982 non-null    int64
#  12  fast_charging              874 non-null    float64
#  13  ram_capacity               981 non-null    float64
#  14  internal_memory            982 non-null    float64
#  15  num_rear_camera            982 non-null    int64
#  16  num_front_camera           926 non-null    object
#  17  screen_size                981 non-null    float64
#  18  resolution                 948 non-null    object
#  19  refresh_rate               982 non-null    int64
#  20  os                         956 non-null    object
#  21  primary_camera_front       926 non-null    object
#  22  extended_memory_available  982 non-null    int64
#  23  extended_upto              320 non-null    object
# dtypes: bool(3), float64(7), int64(5), object(9)
# memory usage: 164.1+ KB

# %%
df['primary_camera_front'].value_counts()
# Out:
# primary_camera_front
# 1    309
# 5    222
# 3    215
# 8    135
# 2     34
# 4      6
# M      2
# 6      2
# U      1
# Name: count, dtype: int64

# %%
df['primary_camera_front'] = pd.to_numeric(
    df['primary_camera_front'].str.extract(r'(\d+\.?\d*)')[0],
    errors='coerce'
)

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core              861
# Hexa Core               30
# Deca Core                8
# Single Core              5
# Quad Core                4
# 2 GHz Processor          2
# 512 MHz Processor        1
# Deca Core Processor      1
# Nine-Cores               1
# Nine Cores               1
# 2.5 GHz Processor        1
# Nine Core                1
# Dual Core                1
# 1.3 GHz Processor        1
# 1.4 GHz Processor        1
# 1.6 GHz Processor        1
# 64 GB inbuilt            1
# Name: count, dtype: int64

# %%
df['num_cores'] = df['num_cores'].str.replace('Octa Core','8')
df['num_cores'] = df['num_cores'].str.replace('Hexa Core','6')
df['num_cores'] = df['num_cores'].str.replace('Quad Core','4')

# %%
df.to_csv('smartphone_cleaned_v3.csv',index=False)

# %%
new_df = pd.read_csv('smartphone_cleaned_v3.csv')

# %%
new_df[['brand_name','model','processor_brand']]
# Out:
#     brand_name                                  model processor_brand
# 0         OPPO                        OPPO Reno 15 5G       dimensity
# 1      Samsung               Samsung Galaxy S24 Ultra      snapdragon
# 2         iQOO                                iQOO 15      snapdragon
# 3       Realme                        Realme GT 8 Pro      snapdragon
# 4       Xiaomi               Xiaomi Redmi K90 Pro Max      snapdragon
# ..         ...                                    ...             ...
# 977    Infinix  Infinix Hot 50 5G (8 GB RAM + 128 GB)       dimensity
# 978       Vivo                         Vivo Y300 Plus      snapdragon
# 979       Oppo                        Oppo A3 5G 2024       dimensity
# 980     Realme                          Realme C63 5G       dimensity
# 981    OnePlus           OnePlus Open 5G Apex Edition      snapdragon
#
# [982 rows x 3 columns]

# %%
new_df['num_cores'] = new_df['num_cores'].str.replace('Octa Core','8')
new_df['num_cores'] = new_df['num_cores'].str.replace('Hexa Core','6')
new_df['num_cores'] = new_df['num_cores'].str.replace('Quad Core','4')

# %%
core_map = {
    'Dual': 2,
    'Quad': 4,
    'Hexa': 6,
    'Octa': 8,
    'Deca': 10
}

new_df['num_cores'] = (
    new_df['num_cores']
    .astype(str)
    .str.extract(r'(Dual|Quad|Hexa|Octa|Deca)', expand=False)
    .map(core_map)
)

# %%
new_df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       381
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand                0
# num_cores                    972
# processor_speed              146
# battery_capacity              26
# fast_charging_available        0
# fast_charging                108
# ram_capacity                   1
# internal_memory                0
# num_rear_camera                0
# num_front_camera              56
# screen_size                    1
# resolution                    34
# refresh_rate                   0
# os                            26
# primary_camera_front          59
# extended_memory_available      0
# extended_upto                662
# dtype: int64

# %%
x_df = new_df.select_dtypes(include='number')

# %%
new_df.select_dtypes(include=['object'])
# Out:
#     brand_name                                  model processor_brand  \
# 0         OPPO                        OPPO Reno 15 5G       dimensity
# 1      Samsung               Samsung Galaxy S24 Ultra      snapdragon
# 2         iQOO                                iQOO 15      snapdragon
# 3       Realme                        Realme GT 8 Pro      snapdragon
# 4       Xiaomi               Xiaomi Redmi K90 Pro Max      snapdragon
# ..         ...                                    ...             ...
# 977    Infinix  Infinix Hot 50 5G (8 GB RAM + 128 GB)       dimensity
# 978       Vivo                         Vivo Y300 Plus      snapdragon
# 979       Oppo                        Oppo A3 5G 2024       dimensity
# 980     Realme                          Realme C63 5G       dimensity
# 981    OnePlus           OnePlus Open 5G Apex Edition      snapdragon
#
#        num_front_camera    resolution       os extended_upto
# 0    50 MP Front Camera  1216 x 2640     other           NaN
# 1    12 MP Front Camera  1440 x 3120   android           NaN
# 2    32 MP Front Camera  1440 x 3168     other           NaN
# 3    32 MP Front Camera  1440 x 3136   android           NaN
# 4    32 MP Front Camera  1200 x 2608     other           NaN
# ..                  ...           ...      ...           ...
# 977   8 MP Front Camera   720 x 1600   android          1024
# 978  32 MP Front Camera  2400 x 1080   android          1024
# 979   5 MP Front Camera   720 x 1604   android          2048
# 980   8 MP Front Camera   720 x 1604   android          2048
# 981                 NaN  2268 x 2440     other           NaN
#
# [982 rows x 7 columns]

# %%
x_df = new_df.select_dtypes(include='number')

# %%
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors=3, weights='distance')
x_array = knn.fit_transform(x_df)

# %%
x_df_imputed = pd.DataFrame(
    x_array,
    columns=x_df.columns,
    index=x_df.index
)

# %%
corr_after = x_df_imputed.corr()['price'].reset_index()
corr_before = x_df.corr()['price'].reset_index()

corr_compare = corr_after.merge(
    corr_before,
    on='index',
    suffixes=('_after_knn', '_before_knn')
)

# %%
new_df = pd.get_dummies(
    new_df,
    columns=['brand_name','processor_brand','os'],
    drop_first=True
)

new_df.head()
# Out:
#                       model  price  rating  has_5g  has_nfc  has_ir_blaster  \
# 0           OPPO Reno 15 5G  39990    90.0    True     True            True
# 1  Samsung Galaxy S24 Ultra  84999    92.0    True     True           False
# 2                   iQOO 15  67999    91.0    True     True            True
# 3           Realme GT 8 Pro  72999    94.0    True     True            True
# 4  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True            True
#
#    num_cores  processor_speed  battery_capacity  fast_charging_available  \
# 0        NaN             3.25            6200.0                        1
# 1        NaN             3.30            5000.0                        1
# 2        NaN             4.60            7000.0                        1
# 3        NaN             4.60            7000.0                        1
# 4        NaN             4.60            7500.0                        1
#
#    fast_charging  ram_capacity  internal_memory  num_rear_camera  \
# 0           80.0          12.0            256.0                3
# 1           45.0          12.0            256.0                4
# 2          100.0          12.0            256.0                3
# 3          120.0          12.0            256.0                3
# 4          100.0          12.0            256.0                3
#
#      num_front_camera  screen_size    resolution  refresh_rate  \
# 0  50 MP Front Camera         6.32  1216 x 2640            120
# 1  12 MP Front Camera         6.80  1440 x 3120            120
# 2  32 MP Front Camera         6.85  1440 x 3168            144
# 3  32 MP Front Camera         6.79  1440 x 3136            144
# 4  32 MP Front Camera         6.90  1200 x 2608            120
#
#    primary_camera_front  extended_memory_available extended_upto  \
# 0                   5.0                          0           NaN
# 1                   1.0                          0           NaN
# 2                   3.0                          0           NaN
# 3                   3.0                          0           NaN
# 4                   3.0                          0           NaN
#
#    brand_name_Ai+  brand_name_Alcatel  brand_name_Apple  brand_name_Asus  \
# 0           False               False             False            False
# 1           False               False             False            False
# 2           False               False             False            False
# 3           False               False             False            False
# 4           False               False             False            False
#
#    brand_name_Bluefox  brand_name_CMF  brand_name_Cubot  brand_name_Doogee  \
# 0               False           False             False              False
# 1               False           False             False              False
# 2               False           False             False              False
# 3               False           False             False              False
# 4               False           False             False              False
#
#    brand_name_Energizer  brand_name_Google  brand_name_HMD  brand_name_Honor  \
# 0                 False              False           False             False
# 1                 False              False           False             False
# 2                 False              False           False             False
# 3                 False              False           False             False
# 4                 False              False           False             False
#
#    brand_name_Huawei  brand_name_Infinix  brand_name_Jio  brand_name_LAVA  \
# 0              False               False           False            False
# 1              False               False           False            False
# 2              False               False           False            False
# 3              False               False           False            False
# 4              False               False           False            False
#
#    brand_name_Lava  brand_name_Light  brand_name_MTR  brand_name_Micromax  \
# 0            False             False           False                False
# 1            False             False           False                False
# 2            False             False           False                False
# 3            False             False           False                False
# 4            False             False           False                False
#
#    brand_name_Motorola  brand_name_Nokia  brand_name_Nothing  \
# 0                False             False               False
# 1                False             False               False
# 2                False             False               False
# 3                False             False               False
# 4                False             False               False
#
#    brand_name_Nubia  brand_name_OPPO  brand_name_OnePlus  brand_name_Oneplus  \
# 0             False             True               False               False
# 1             False            False               False               False
# 2             False            False               False               False
# 3             False            False               False               False
# 4             False            False               False               False
#
#    brand_name_Oppo  brand_name_Oukitel  brand_name_POCO  brand_name_Peace  \
# 0            False               False            False             False
# 1            False               False            False             False
# 2            False               False            False             False
# 3            False               False            False             False
# 4            False               False            False             False
#
#    brand_name_Poco  brand_name_Realme  brand_name_Red  brand_name_RedMagic  \
# 0            False              False           False                False
# 1            False              False           False                False
# 2            False              False           False                False
# 3            False               True           False                False
# 4            False              False           False                False
#
#    brand_name_Redmi  brand_name_Samsung  brand_name_Sony  brand_name_Tecno  \
# 0             False               False            False             False
# 1             False                True            False             False
# 2             False               False            False             False
# 3             False               False            False             False
# 4             False               False            False             False
#
#    brand_name_Tesla  brand_name_Ulefone  brand_name_Unihertz  \
# 0             False               False                False
# 1             False               False                False
# 2             False               False                False
# 3             False               False                False
# 4             False               False                False
#
#    brand_name_Vertu  brand_name_Vivo  brand_name_Wobble  brand_name_Xiaomi  \
# 0             False            False              False              False
# 1             False            False              False              False
# 2             False            False              False              False
# 3             False            False              False              False
# 4             False            False              False               True
#
#    brand_name_ZTE  brand_name_iKall  brand_name_iQOO  brand_name_itel  \
# 0           False             False            False            False
# 1           False             False            False            False
# 2           False             False             True            False
# 3           False             False            False            False
# 4           False             False            False            False
#
#    processor_brand_4  processor_brand_bionic  processor_brand_dimensity  \
# 0              False                   False                       True
# 1              False                   False                      False
# 2              False                   False                      False
# 3              False                   False                      False
# 4              False                   False                      False
#
#    processor_brand_exynos  processor_brand_google  processor_brand_helio  \
# 0                   False                   False                  False
# 1                   False                   False                  False
# 2                   False                   False                  False
# 3                   False                   False                  False
# 4                   False                   False                  False
#
#    processor_brand_kirin  processor_brand_mediatek  processor_brand_no  \
# 0                  False                     False               False
# 1                  False                     False               False
# 2                  False                     False               False
# 3                  False                     False               False
# 4                  False                     False               False
#
#    processor_brand_octa  processor_brand_quad  processor_brand_snapdragon  \
# 0                 False                 False                       False
# 1                 False                 False                        True
# 2                 False                 False                        True
# 3                 False                 False                        True
# 4                 False                 False                        True
#
#    processor_brand_tensor  processor_brand_tiger  processor_brand_unisoc  \
# 0                   False                  False                   False
# 1                   False                  False                   False
# 2                   False                  False                   False
# 3                   False                  False                   False
# 4                   False                  False                   False
#
#    os_ios  os_other
# 0   False      True
# 1   False     False
# 2   False      True
# 3   False     False
# 4   False      True

# %%
new_df.to_csv('smartphones_cleaned_v5.csv', index=False)
