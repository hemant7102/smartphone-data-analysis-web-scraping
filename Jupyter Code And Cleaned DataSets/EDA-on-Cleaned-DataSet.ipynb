# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv('smartphone_cleaned_v3.csv')

# %%
df.shape
# Out:
# (982, 24)

# %%
df.head()
# Out:
#   brand_name                     model  price  rating  has_5g  has_nfc  \
# 0       OPPO           OPPO Reno 15 5G  39990    90.0    True     True
# 1    Samsung  Samsung Galaxy S24 Ultra  84999    92.0    True     True
# 2       iQOO                   iQOO 15  67999    91.0    True     True
# 3     Realme           Realme GT 8 Pro  72999    94.0    True     True
# 4     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True
#
#    has_ir_blaster processor_brand num_cores  processor_speed  \
# 0            True       dimensity         8             3.25
# 1           False      snapdragon         8             3.30
# 2            True      snapdragon         8             4.60
# 3            True      snapdragon         8             4.60
# 4            True      snapdragon         8             4.60
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            6200.0                        1           80.0          12.0
# 1            5000.0                        1           45.0          12.0
# 2            7000.0                        1          100.0          12.0
# 3            7000.0                        1          120.0          12.0
# 4            7500.0                        1          100.0          12.0
#
#    internal_memory  num_rear_camera    num_front_camera  screen_size  \
# 0            256.0                3  50 MP Front Camera         6.32
# 1            256.0                4  12 MP Front Camera         6.80
# 2            256.0                3  32 MP Front Camera         6.85
# 3            256.0                3  32 MP Front Camera         6.79
# 4            256.0                3  32 MP Front Camera         6.90
#
#      resolution  refresh_rate       os  primary_camera_front  \
# 0  1216 x 2640            120    other                   5.0
# 1  1440 x 3120            120  android                   1.0
# 2  1440 x 3168            144    other                   3.0
# 3  1440 x 3136            144  android                   3.0
# 4  1200 x 2608            120    other                   3.0
#
#    extended_memory_available extended_upto
# 0                          0           NaN
# 1                          0           NaN
# 2                          0           NaN
# 3                          0           NaN
# 4                          0           NaN

# %% [markdown]
# ## brand name

# %%
# plot a graph of top 5 brands
df['brand_name'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand_name'>

# %%
# pie chart
df['brand_name'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['brand_name'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## model

# %%
df['model'].nunique()
# Out:
# 982

# %% [markdown]
# ## price

# %%
df['price'].describe()
# Out:
# count       982.000000
# mean      36762.934827
# std       41316.272266
# min        3499.000000
# 25%       15169.250000
# 50%       23999.000000
# 75%       40742.250000
# max      489990.000000
# Name: price, dtype: float64

# %%
sns.displot(kind='hist',data=df,x='price',kde=True)

# %%
df['price'].skew()
# Out:
# np.float64(4.766547724943288)

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
df[df['price'] > 250000]
# Out:
#     brand_name                                   model   price  rating  \
# 504      Vertu                          Vertu Ironflip  489990    84.0
# 811      Vertu                       Vertu Metavertu 2  425999    86.0
# 925     Xiaomi  Xiaomi Redmi K20 Pro Signature Edition  480000    86.0
#
#      has_5g  has_nfc  has_ir_blaster processor_brand num_cores  \
# 504    True     True           False      snapdragon         8
# 811    True     True           False      snapdragon         8
# 925   False     True           False      snapdragon         8
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 504              3.2            4310.0                        1
# 811              3.2            5100.0                        1
# 925              2.8            4000.0                        1
#
#      fast_charging  ram_capacity  internal_memory  num_rear_camera  \
# 504           65.0          12.0            256.0                2
# 811           65.0          12.0            512.0                3
# 925           27.0           8.0            256.0                3
#
#        num_front_camera  screen_size    resolution  refresh_rate       os  \
# 504                 NaN         6.70  2790 x 1188            120  android
# 811  16 MP Front Camera         6.78  1260 x 2800            120  android
# 925  20 MP Front Camera         6.39  1080 x 2340             60  android
#
#      primary_camera_front  extended_memory_available extended_upto
# 504                   NaN                          0           NaN
# 811                   1.0                          0           NaN
# 925                   2.0                          0           NaN

# %%
df['price'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['rating'].describe()
# Out:
# count    601.000000
# mean      85.183028
# std        3.879834
# min       80.000000
# 25%       82.000000
# 50%       84.000000
# 75%       87.000000
# max       97.000000
# Name: rating, dtype: float64

# %%
sns.displot(kind='hist',data=df,x='rating',kde=True)

# %%
df['rating'].skew()
# Out:
# np.float64(0.7579857188406607)

# %%
sns.boxplot(df['rating'])
# Out:
# <Axes: ylabel='rating'>

# %%
df['rating'].isnull().sum()/980
# Out:
# np.float64(0.38877551020408163)

# %%
df.head()
# Out:
#   brand_name                     model  price  rating  has_5g  has_nfc  \
# 0       OPPO           OPPO Reno 15 5G  39990    90.0    True     True
# 1    Samsung  Samsung Galaxy S24 Ultra  84999    92.0    True     True
# 2       iQOO                   iQOO 15  67999    91.0    True     True
# 3     Realme           Realme GT 8 Pro  72999    94.0    True     True
# 4     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True
#
#    has_ir_blaster processor_brand num_cores  processor_speed  \
# 0            True       dimensity         8             3.25
# 1           False      snapdragon         8             3.30
# 2            True      snapdragon         8             4.60
# 3            True      snapdragon         8             4.60
# 4            True      snapdragon         8             4.60
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            6200.0                        1           80.0          12.0
# 1            5000.0                        1           45.0          12.0
# 2            7000.0                        1          100.0          12.0
# 3            7000.0                        1          120.0          12.0
# 4            7500.0                        1          100.0          12.0
#
#    internal_memory  num_rear_camera    num_front_camera  screen_size  \
# 0            256.0                3  50 MP Front Camera         6.32
# 1            256.0                4  12 MP Front Camera         6.80
# 2            256.0                3  32 MP Front Camera         6.85
# 3            256.0                3  32 MP Front Camera         6.79
# 4            256.0                3  32 MP Front Camera         6.90
#
#      resolution  refresh_rate       os  primary_camera_front  \
# 0  1216 x 2640            120    other                   5.0
# 1  1440 x 3120            120  android                   1.0
# 2  1440 x 3168            144    other                   3.0
# 3  1440 x 3136            144  android                   3.0
# 4  1200 x 2608            120    other                   3.0
#
#    extended_memory_available extended_upto
# 0                          0           NaN
# 1                          0           NaN
# 2                          0           NaN
# 3                          0           NaN
# 4                          0           NaN

# %% [markdown]
# ## has_5g

# %%
df['has_5g'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## has_nfc

# %%
df['has_nfc'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## has_ir_blaster

# %%
df['has_ir_blaster'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df[df['has_ir_blaster'] == True]['brand_name'].value_counts()
# Out:
# brand_name
# Xiaomi      54
# Vivo        52
# OnePlus     39
# Realme      33
# Poco        31
# iQOO        29
# Oppo        26
# Tecno       26
# Infinix     25
# OPPO        21
# Honor       15
# Nubia        6
# Huawei       5
# itel         4
# Oneplus      3
# Ulefone      2
# Bluefox      1
# Red          1
# RedMagic     1
# Unihertz     1
# Samsung      1
# Apple        1
# Redmi        1
# Name: count, dtype: int64

# %%
df['processor_brand'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['num_cores'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['fast_charging_available'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['ram_capacity'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['internal_memory'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['refresh_rate'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['refresh_rate'].value_counts()
# Out:
# refresh_rate
# 120    656
# 144    126
# 60     106
# 90      77
# 165     15
# 185      2
# Name: count, dtype: int64

# %%
(df['num_rear_camera'] + df['num_rear_camera']).value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['os'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## extended_memory_available

# %%
df['extended_memory_available'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['extended_upto'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
num_columns = df.select_dtypes(include='number').columns

# %%
def plot_graphs(column_name):
    sns.displot(data=df, x=column_name, kde=True)
    plt.show()
    plt.close()

    sns.boxplot(data=df, x=column_name)
    plt.show()
    plt.close()

# %%
for col in num_columns[:3]:
    plot_graphs(col)

# %%
df.head()
# Out:
#   brand_name                     model  price  rating  has_5g  has_nfc  \
# 0       OPPO           OPPO Reno 15 5G  39990    90.0    True     True
# 1    Samsung  Samsung Galaxy S24 Ultra  84999    92.0    True     True
# 2       iQOO                   iQOO 15  67999    91.0    True     True
# 3     Realme           Realme GT 8 Pro  72999    94.0    True     True
# 4     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True
#
#    has_ir_blaster processor_brand num_cores  processor_speed  \
# 0            True       dimensity         8             3.25
# 1           False      snapdragon         8             3.30
# 2            True      snapdragon         8             4.60
# 3            True      snapdragon         8             4.60
# 4            True      snapdragon         8             4.60
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            6200.0                        1           80.0          12.0
# 1            5000.0                        1           45.0          12.0
# 2            7000.0                        1          100.0          12.0
# 3            7000.0                        1          120.0          12.0
# 4            7500.0                        1          100.0          12.0
#
#    internal_memory  num_rear_camera    num_front_camera  screen_size  \
# 0            256.0                3  50 MP Front Camera         6.32
# 1            256.0                4  12 MP Front Camera         6.80
# 2            256.0                3  32 MP Front Camera         6.85
# 3            256.0                3  32 MP Front Camera         6.79
# 4            256.0                3  32 MP Front Camera         6.90
#
#      resolution  refresh_rate       os  primary_camera_front  \
# 0  1216 x 2640            120    other                   5.0
# 1  1440 x 3120            120  android                   1.0
# 2  1440 x 3168            144    other                   3.0
# 3  1440 x 3136            144  android                   3.0
# 4  1200 x 2608            120    other                   3.0
#
#    extended_memory_available extended_upto
# 0                          0           NaN
# 1                          0           NaN
# 2                          0           NaN
# 3                          0           NaN
# 4                          0           NaN

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x='brand_name',y='price')
plt.xticks(rotation='vertical')
plt.show()

# %%
x = df.groupby('brand_name').count()['model']

# %%
temp_df = df[df['brand_name'].isin(x[x > 10].index)]

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=temp_df,x='brand_name',y='price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   brand_name                     model  price  rating  has_5g  has_nfc  \
# 0       OPPO           OPPO Reno 15 5G  39990    90.0    True     True
# 1    Samsung  Samsung Galaxy S24 Ultra  84999    92.0    True     True
# 2       iQOO                   iQOO 15  67999    91.0    True     True
# 3     Realme           Realme GT 8 Pro  72999    94.0    True     True
# 4     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True
#
#    has_ir_blaster processor_brand num_cores  processor_speed  \
# 0            True       dimensity         8             3.25
# 1           False      snapdragon         8             3.30
# 2            True      snapdragon         8             4.60
# 3            True      snapdragon         8             4.60
# 4            True      snapdragon         8             4.60
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            6200.0                        1           80.0          12.0
# 1            5000.0                        1           45.0          12.0
# 2            7000.0                        1          100.0          12.0
# 3            7000.0                        1          120.0          12.0
# 4            7500.0                        1          100.0          12.0
#
#    internal_memory  num_rear_camera    num_front_camera  screen_size  \
# 0            256.0                3  50 MP Front Camera         6.32
# 1            256.0                4  12 MP Front Camera         6.80
# 2            256.0                3  32 MP Front Camera         6.85
# 3            256.0                3  32 MP Front Camera         6.79
# 4            256.0                3  32 MP Front Camera         6.90
#
#      resolution  refresh_rate       os  primary_camera_front  \
# 0  1216 x 2640            120    other                   5.0
# 1  1440 x 3120            120  android                   1.0
# 2  1440 x 3168            144    other                   3.0
# 3  1440 x 3136            144  android                   3.0
# 4  1200 x 2608            120    other                   3.0
#
#    extended_memory_available extended_upto
# 0                          0           NaN
# 1                          0           NaN
# 2                          0           NaN
# 3                          0           NaN
# 4                          0           NaN

# %%
sns.scatterplot(data=df,x='rating',y='price')
# Out:
# <Axes: xlabel='rating', ylabel='price'>

# %%
sns.barplot(data=temp_df,x='has_5g',y='price',estimator=np.median)
# Out:
# <Axes: xlabel='has_5g', ylabel='price'>

# %%
sns.pointplot(data=temp_df,x='has_nfc',y='price',estimator=np.median)
# Out:
# <Axes: xlabel='has_nfc', ylabel='price'>

# %%
sns.barplot(data=temp_df,x='has_ir_blaster',y='price',estimator=np.median)
# Out:
# <Axes: xlabel='has_ir_blaster', ylabel='price'>

# %%
sns.barplot(data=temp_df,x='processor_brand',y='price',estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(data=temp_df,x='num_cores',y='price',estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
pd.crosstab(df['num_cores'],df['os'])
# Out:
# os                   android  ios  other
# num_cores
# 1.3 GHz Processor          1    0      0
# 1.4 GHz Processor          1    0      0
# 1.6 GHz Processor          1    0      0
# 2 GHz Processor            2    0      0
# 2.5 GHz Processor          1    0      0
# 4                          1    0      2
# 512 MHz Processor          0    0      1
# 6                          0   28      2
# 64 GB inbuilt              0    0      1
# 8                        523    0    315
# Deca Core                  4    0      3
# Deca Core Processor        1    0      0
# Nine Core                  0    0      1
# Nine Cores                 0    0      1
# Nine-Cores                 1    0      0
# Single Core                0    0      5

# %%
sns.scatterplot(data=df,x='processor_speed',y='price')
# Out:
# <Axes: xlabel='processor_speed', ylabel='price'>

# %%
sns.scatterplot(data=df,x='screen_size',y='price')
# Out:
# <Axes: xlabel='screen_size', ylabel='price'>

# %%
df.corr(numeric_only=True)['price']
# Out:
# price                        1.000000
# rating                       0.429117
# has_5g                       0.178708
# has_nfc                      0.390257
# has_ir_blaster               0.064406
# processor_speed              0.561813
# battery_capacity            -0.042013
# fast_charging_available      0.078196
# fast_charging                0.252847
# ram_capacity                 0.020618
# internal_memory              0.519180
# num_rear_camera              0.297838
# screen_size                 -0.003114
# refresh_rate                 0.071698
# primary_camera_front        -0.235049
# extended_memory_available   -0.383716
# Name: price, dtype: float64

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       381
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand                0
# num_cores                     61
# processor_speed              146
# battery_capacity              26
# fast_charging_available        0
# fast_charging                108
# ram_capacity                   1
# internal_memory                0
# num_rear_camera                0
# num_front_camera              56
# screen_size                    1
# resolution                    34
# refresh_rate                   0
# os                            26
# primary_camera_front          59
# extended_memory_available      0
# extended_upto                662
# dtype: int64

# %%
df.corr(numeric_only=True)['rating']
# Out:
# price                        0.429117
# rating                       1.000000
# has_5g                       0.120361
# has_nfc                      0.408305
# has_ir_blaster               0.202610
# processor_speed              0.665098
# battery_capacity             0.129234
# fast_charging_available     -0.004889
# fast_charging                0.244272
# ram_capacity                 0.603119
# internal_memory              0.520909
# num_rear_camera              0.301615
# screen_size                  0.021143
# refresh_rate                 0.111747
# primary_camera_front         0.203510
# extended_memory_available   -0.288132
# Name: rating, dtype: float64

# %% [markdown]
# ## knn imputer

# %%
x_df = df.select_dtypes(include=['int64','float64']).drop(columns='price')

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
x_df_values = imputer.fit_transform(x_df)

# %%
x_df = pd.DataFrame(x_df_values,columns=x_df.columns)

# %%
x_df['price'] = df['price']

# %%
x_df.head()
# Out:
#    rating  processor_speed  battery_capacity  fast_charging_available  \
# 0    90.0             3.25            6200.0                      1.0
# 1    92.0             3.30            5000.0                      1.0
# 2    91.0             4.60            7000.0                      1.0
# 3    94.0             4.60            7000.0                      1.0
# 4    91.0             4.60            7500.0                      1.0
#
#    fast_charging  ram_capacity  internal_memory  num_rear_camera  screen_size  \
# 0           80.0          12.0            256.0              3.0         6.32
# 1           45.0          12.0            256.0              4.0         6.80
# 2          100.0          12.0            256.0              3.0         6.85
# 3          120.0          12.0            256.0              3.0         6.79
# 4          100.0          12.0            256.0              3.0         6.90
#
#    refresh_rate  primary_camera_front  extended_memory_available  price
# 0         120.0                   5.0                        0.0  39990
# 1         120.0                   1.0                        0.0  84999
# 2         144.0                   3.0                        0.0  67999
# 3         144.0                   3.0                        0.0  72999
# 4         120.0                   3.0                        0.0  50990

# %%
a = x_df.corr()['price'].reset_index()

# %%
b = df.corr(numeric_only=True)['price'].reset_index()

# %%
b.merge(a,on='index')
# Out:
#                         index   price_x   price_y
# 0                       price  1.000000  1.000000
# 1                      rating  0.429117  0.497361
# 2             processor_speed  0.561813  0.517796
# 3            battery_capacity -0.042013 -0.038389
# 4     fast_charging_available  0.078196  0.078196
# 5               fast_charging  0.252847  0.219647
# 6                ram_capacity  0.020618  0.020540
# 7             internal_memory  0.519180  0.519180
# 8             num_rear_camera  0.297838  0.297838
# 9                 screen_size -0.003114  0.018279
# 10               refresh_rate  0.071698  0.071698
# 11       primary_camera_front -0.235049 -0.207156
# 12  extended_memory_available -0.383716 -0.383716

# %%
pd.get_dummies(
    df,
    columns=['brand_name','processor_brand','os'],
    drop_first=True
).corr(numeric_only=True)['price']
# Out:
# price                         1.000000
# rating                        0.429117
# has_5g                        0.178708
# has_nfc                       0.390257
# has_ir_blaster                0.064406
# processor_speed               0.561813
# battery_capacity             -0.042013
# fast_charging_available       0.078196
# fast_charging                 0.252847
# ram_capacity                  0.020618
# internal_memory               0.519180
# num_rear_camera               0.297838
# screen_size                  -0.003114
# refresh_rate                  0.071698
# primary_camera_front         -0.235049
# extended_memory_available    -0.383716
# brand_name_Ai+               -0.044477
# brand_name_Alcatel           -0.022715
# brand_name_Apple              0.316376
# brand_name_Asus               0.114179
# brand_name_Bluefox           -0.021698
# brand_name_CMF               -0.029079
# brand_name_Cubot             -0.009102
# brand_name_Doogee             0.000800
# brand_name_Energizer         -0.010649
# brand_name_Google             0.100761
# brand_name_HMD               -0.040134
# brand_name_Honor              0.006979
# brand_name_Huawei             0.165660
# brand_name_Infinix           -0.090444
# brand_name_Jio               -0.032292
# brand_name_LAVA              -0.021088
# brand_name_Lava              -0.097669
# brand_name_Light             -0.008503
# brand_name_MTR               -0.025177
# brand_name_Micromax          -0.022182
# brand_name_Motorola          -0.078406
# brand_name_Nokia             -0.031714
# brand_name_Nothing           -0.018340
# brand_name_Nubia              0.023316
# brand_name_OPPO              -0.026297
# brand_name_OnePlus            0.029093
# brand_name_Oneplus            0.044541
# brand_name_Oppo              -0.020546
# brand_name_Oukitel           -0.011397
# brand_name_POCO              -0.033108
# brand_name_Peace             -0.060056
# brand_name_Poco              -0.067517
# brand_name_Realme            -0.106732
# brand_name_Red                0.018731
# brand_name_RedMagic           0.025690
# brand_name_Redmi             -0.002917
# brand_name_Samsung            0.077988
# brand_name_Sony               0.062604
# brand_name_Tecno             -0.078969
# brand_name_Tesla              0.025697
# brand_name_Ulefone            0.045927
# brand_name_Unihertz          -0.001371
# brand_name_Vertu              0.460811
# brand_name_Vivo              -0.027008
# brand_name_Wobble            -0.011414
# brand_name_Xiaomi             0.025690
# brand_name_ZTE               -0.009095
# brand_name_iKall             -0.023476
# brand_name_iQOO              -0.013392
# brand_name_itel              -0.045470
# processor_brand_4            -0.022239
# processor_brand_bionic        0.282870
# processor_brand_dimensity    -0.210489
# processor_brand_exynos       -0.035852
# processor_brand_google       -0.009335
# processor_brand_helio        -0.130529
# processor_brand_kirin         0.063574
# processor_brand_mediatek     -0.019146
# processor_brand_no           -0.035706
# processor_brand_octa          0.090167
# processor_brand_quad         -0.033933
# processor_brand_snapdragon    0.169104
# processor_brand_tensor        0.113070
# processor_brand_tiger        -0.019153
# processor_brand_unisoc       -0.137539
# os_ios                        0.304843
# os_other                      0.123762
# Name: price, dtype: float64

# %%
df.head()
# Out:
#   brand_name                     model  price  rating  has_5g  has_nfc  \
# 0       OPPO           OPPO Reno 15 5G  39990    90.0    True     True
# 1    Samsung  Samsung Galaxy S24 Ultra  84999    92.0    True     True
# 2       iQOO                   iQOO 15  67999    91.0    True     True
# 3     Realme           Realme GT 8 Pro  72999    94.0    True     True
# 4     Xiaomi  Xiaomi Redmi K90 Pro Max  50990    91.0    True     True
#
#    has_ir_blaster processor_brand num_cores  processor_speed  \
# 0            True       dimensity         8             3.25
# 1           False      snapdragon         8             3.30
# 2            True      snapdragon         8             4.60
# 3            True      snapdragon         8             4.60
# 4            True      snapdragon         8             4.60
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            6200.0                        1           80.0          12.0
# 1            5000.0                        1           45.0          12.0
# 2            7000.0                        1          100.0          12.0
# 3            7000.0                        1          120.0          12.0
# 4            7500.0                        1          100.0          12.0
#
#    internal_memory  num_rear_camera    num_front_camera  screen_size  \
# 0            256.0                3  50 MP Front Camera         6.32
# 1            256.0                4  12 MP Front Camera         6.80
# 2            256.0                3  32 MP Front Camera         6.85
# 3            256.0                3  32 MP Front Camera         6.79
# 4            256.0                3  32 MP Front Camera         6.90
#
#      resolution  refresh_rate       os  primary_camera_front  \
# 0  1216 x 2640            120    other                   5.0
# 1  1440 x 3120            120  android                   1.0
# 2  1440 x 3168            144    other                   3.0
# 3  1440 x 3136            144  android                   3.0
# 4  1200 x 2608            120    other                   3.0
#
#    extended_memory_available extended_upto
# 0                          0           NaN
# 1                          0           NaN
# 2                          0           NaN
# 3                          0           NaN
# 4                          0           NaN

# %%
df.to_csv('smartphone_final_cleaned.csv',index=False)
